# %%
import os                      
import numpy as np              
import pandas as pd  
from pandas import DataFrame
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.text import Text
import glob
import spacy
from collections import Counter
nlp = spacy.load("da_core_news_lg")

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mette\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
samlede_nemme0 = []

path = os.path.join("Nemme")

for fil in os.scandir(path):
    with open (fil, encoding = "utf8") as f:
        samlede_nemme0.append(f.read())

# %%
samlede_nemme1= "".join(samlede_nemme0)

# %%
text_lower_nemme = samlede_nemme1.lower()

# %%
samlede_nemme2 = text_lower_nemme.replace("."," ")

# %%
AntalTegnNemme = len(samlede_nemme2)

# %%
AntalTegnNemme
# Out:
# 112195

# %%
tokens_nemme=nltk.word_tokenize(samlede_nemme2)

# %%
txt = tokens_nemme
bestemtestrikkeord_dictionary={"kantmasken":1,"kantmaskerne":1, "rundpinden":1, "rundpindene":1, "bærestykket":1, "masken":1, "maskerne":1, "ærmegabet":1, "maskemarkøren":1, "maskemarkørerne":1, "markøren":1, "markørerne":1, "aflukningen":1, "aflukningerne":1, "opslagskanten":1, "opslagskanterne":1, "lænken":1, "lænkerne":1, "knaphullet":1, "knaphullerne":1, "strømpepinden":1, "strømpepinde":1,"strømpepindene":1, "omslaget":1, "omslagene":1, "indtagningen":1, "indtagninggerne":1, "ribben":1, "ribkanten":1, "ribkanterne":1, "rillekanten":1, "rillekanterne":1, "raglanen":1, "raglansømmene":1, "sømmene":1, "mærketråden":1, "mærketrådene":1, "retsidepinden":1, "retsidepindene":1, "maskeholderen":1, "maskeholderne":1, "løkkeopslaget":1, "løkkeopslagene":1, "blokken":1, "blokkene":1, "mønsteret":1,  "mønstrene":1, "ærmekuppelen":1, "ærmekuplerne":1, "vendepinden":1, "vendepindene":1, "boblen":1, "boblerne":1,   "skulderaflukningen":1, "skuldersømmen":1, "skuldersømmene":1, "retsidepinden":1, "retsidepindene":1, "elastikken":1, "elastikkerne":1, "elastiksnoren":1, "elastiksnorer":1, "elastiksnorene":1, "sildebensmønsteret":1, "overtræksindtagningen":1, "sidesømsmarkøren":1, "sidesømsmarkørene":1, "ærmesømmen":1, "ærmesømmene":1, "raglanindtagningen":1, "raglanindtagningerne":1}
score_bestemte = 0

for w in txt:
    for k, v in bestemtestrikkeord_dictionary.items():
        if w == k:
            score_bestemte = score_bestemte + v
            print("Item score:", k, v)
            
print("Samlet score: ", score_bestemte)
# Out:
# Item score: ærmegabet 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: rundpinden 1
# Item score: rundpinden 1
# Item score: ærmegabet 1
# Item score: maskerne 1
# Item score: ærmegabet 1
# Item score: skuldersømmene 1
# Item score: ærmegabet 1
# Item score: maskerne 1
# Item score: bærestykket 1
# Item score: rundpinden 1
# Item score: bærestykket 1
# Item score: omslaget 1
# Item score: markøren 1
# Item score: markøren 1
# Item score: markøren 1
# Item score: maskerne 1
# Item score: masken 1
# Item score: markøren 1
# Item score: markøren 1
# Item score: strømpepinde 1
# Item score: omslagene 1
# Item score: mærketråden 1
# Item score: mærketråden 1
# Item score: masken 1
":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score0 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score0 = score0 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score0)
# Out:
# Item score: ærmegab 1
# Item score: masker 1
# Item score: ærmegabet 1
# Item score: maske 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: rib 2
# Item score: drejet 2
# Item score: ret 1
# Item score: drejet 2
# Item score: vrang 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: ret 1
# Item score: maske 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: markør 1
# Item score: masker 1
# Item score: ryg 1
# Item score: forstykke 1
# Item score: ærmegab 1
# Item score: masker 1
# Item score: rundpinden 1
# Item score: ryg 1
# Item score: glatstrik 1
# Item score: rundpinden 1
# Item score: ærmegabet 1
# Item score: maskerne 1
# Item score: forstykke 1
# Item score: ærmegabet 1
# Item score: masker 1
# Item score: forstykke 1
# Item score: vrang 1
# Item score: masker 1
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# ...

# %%
txt=tokens_nemme
allestrikkeord_dictionary={"ret":"Nem", "vrang":"Nem", "retmaske":"Nem", "vrangmaske":"Nem", "retstrik":"Nem", "glatstrik":"Nem", "kantmaske":"Nem", "kantmasken":"Nem", "kantmasker":"Nem", "kantmaskerne":"Nem", "løkkeopslag":"Nem", "rundpind":"Nem", "rundpinden":"Nem", "rundpinde":"Nem", "rundpindene":"Nem", "bærestykke":"Nem", "bærestykket":"Nem", "maske":"Nem", "masken":"Nem", "masker":"Nem", "maskerne":"Nem", "ærmegab":"Nem", "ærmegabet":"Nem", "maskemarkør":"Nem", "maskemarkøren":"Nem", "maskemarkører":"Nem", "maskemarkørerne":"Nem", "markør":"Nem", "markøren":"Nem", "markører":"Nem", "markørerne":"Nem", "aflukning":"Nem", "aflukningen":"Nem", "aflukninger":"Nem", "aflukningerne":"Nem",  "opslagskant":"Nem", "opslagskanten":"Nem", "opslagskanter":"Nem", "opslagskanterne":"Nem", "lænke":"Nem", "lænken":"Nem", "lænker":"Nem", "lænkerne":"Nem", "omgangsstart":"Nem", "forstykke":"Nem", "bagstykke":"Nem", "ryg":"Nem", "r":"Forkortelser", "vr":"Forkortelser", "omg":"Forkortelser", "indt":"Forkortelser", "udt":"Forkortelser", "m":"Forkortelser", "p":"Forkortelser", "gent":"Forkortelser", "sm":"Forkortelser", "mm":"Forkortelser", "arb":"Forkortelser", "km":"Forkortelser", "vrs":"Forkortelser", "vrangs":"Forkortelser", "rts":"Forkortelser", "rundp":"Forkortelser", "fv":"Forkortelser", "kantm":"Forkortelser", "enkeltindt":"Forkortelser", "raglanindt":"Forkortelser", "glatst":"Forkortelser", "knaphul":"Middel", "knaphullet":"Middel", "knaphuller":"Middel", "knaphullerne":"Middel", "drejet":"Middel", "drejet ret":"Middel", "drejet vrang":"Middel", "strømpepind":"Middel", "strømpepinden":"Middel", "strømpepinde":"Middel","strømpepindene":"Middel", "omslag":"Middel", "omslaget":"Middel", "omslagene":"Middel", "indtagning":"Middel", "indtagningen":"Middel", "indtagninger":"Middel", "indtagninggerne":"Middel", "rib":"Middel", "ribben":"Middel", "ribbort":"Middel", "ribpind":"Middel", "ribkant":"Middel", "ribkanten":"Middel", "ribkanter":"Middel", "ribkanterne":"Middel", "rillekant":"Middel", "rillekanten":"Middel", "rillekanter":"Middel", "rillekanterne":"Middel", "magic loop":"Middel", "magic loops":"Middel", "raglan":"Middel", "raglanen":"Middel", "raglansøm":"Middel", "raglansømmene":"Middel", "søm":"Middel", "sømme":"Middel", "sømmene":"Middel", "sømrum":"Middel", "mærketråd":"Middel", "mærketråden":"Middel", "mærketråde":"Middel", "mærketrådene":"Middel", "italiensk aflukning":"Middel", "italienske aflukninger":"Middel", "retsidepind":"Middel", "retsidepinden":"Middel", "retsidepindene":"Middel", "retsidepindene":"Middel", "maskeholder":"Middel", "maskeholderen":"Middel", "maskeholder":"Middel", "maskeholderne":"Middel", "løkkeopslag":"Middel", "løkkeopslaget":"Middel", "løkkeopslagene":"Middel", "blok":"Middel", "blokken":"Middel", "blokke":"Middel", "blokkene":"Middel", "mønster":"Svær", "mønsteret":"Svær", "mønstre":"Svær", "mønstrene":"Svær", "ærmekuppel":"Svær", "ærmekuppelen":"Svær", "ærmekupler":"Svær", "ærmekuplerne":"Svær", "vendepind":"Svær", "vendepinden":"Svær", "vendepinde":"Svær", "vendepindene":"Svær", "diagram":"Svær", "boble":"Svær", "boblen":"Svær", "bobler":"Svær", "boblerne":"Svær", "dobbelt omslag":"Svær", "hulmønster":"Svær", "hulmønstre":"Svær", "montering":"Svær", "skulderaflukning":"Svær", "skulderaflukningen":"Svær", "skulderaflukninger":"Svær", "skuldersøm":"Svær", "skuldersømmen":"Svær", "skuldersømmene":"Svær", "retsidepind":"Svær", "retsidepinden":"Svær", "retsidepinde":"Svær", "retsidepindene":"Svær", "elastik":"Svær", "elastikken":"Svær", "elastikker":"Svær", "elastikkerne":"Svær", "elastiksnor":"Svær", "elastiksnoren":"Svær", "elastiksnorer":"Svær", "elastiksnorene":"Svær", "german short row":"Svær", "german short rows":"Svær", "sildebensmønster":"Svær", "sildebensmønsteret":"Svær", "overtræksindtagning":"Svær", "overtræksindtagningen":"Svær", "mønsterbort":"Svær", "sidesømsmarkør":"Svær", "sidesømsmarkøren":"Svær", "sidesømsmarkører":"Svær", "sidesømsmarkørene":"Svær", "ærmesøm":"Svær", "ærmesømmen":"Svær", "ærmesømme":"Svær", "ærmesømmene":"Svær", "raglanindtagning":"Svær", "raglanindtagningen":"Svær", "raglanindtagninger":"Svær", "raglanindtagningerne":"Svær"}
score = []
for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w==k:
            score.append(v)
            
Counter(score)
# Out:
# Counter({'Nem': 1922, 'Middel': 333, 'Forkortelser': 747, 'Svær': 72})

# %%
# Aline_sweater

# %%
text_Aline= 'Nemme/Aline_sweater.txt'

with open(text_Aline, encoding="utf8") as f:
    Aline_str = f.read()

f.close()

# %%
text_lower = Aline_str.lower()

# %%
textpunkt0 = text_lower.replace("."," ")

# %%
AntalTegn0 = len(textpunkt0)

# %%
AntalTegn0
# Out:
# 3078

# %%
tokens0=nltk.word_tokenize(textpunkt0)

# %%
txt = tokens0
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score0 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score0 = score0 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score0)
# Out:
# Item score: ærmegab 1
# Item score: masker 1
# Item score: ærmegabet 1
# Item score: maske 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: rib 2
# Item score: drejet 2
# Item score: ret 1
# Item score: drejet 2
# Item score: vrang 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: ret 1
# Item score: maske 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: markør 1
# Item score: masker 1
# Item score: ryg 1
# Item score: forstykke 1
# Item score: ærmegab 1
# Item score: masker 1
# Item score: rundpinden 1
# Item score: ryg 1
# Item score: glatstrik 1
# Item score: rundpinden 1
# Item score: ærmegabet 1
# Item score: maskerne 1
# Item score: forstykke 1
# Item score: ærmegabet 1
# Item score: masker 1
# Item score: forstykke 1
# Item score: vrang 1
# Item score: masker 1
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# ...

# %%
RettetScore0=score0/AntalTegn0*100
RettetScore0
# Out:
# 3.41130604288499

# %%
# Angela_bluse

# %%
text_Angela= 'Nemme/Angela_bluse.txt'
with open(text_Angela, encoding="utf8") as f:
    Angela_str = f.read()

f.close()

# %%
text_lower1 = Angela_str.lower()

# %%
textpunkt1 = text_lower1.replace("."," ")

# %%
AntalTegn1 = len(textpunkt1)

# %%
AntalTegn1
# Out:
# 2208

# %%
tokens1=nltk.word_tokenize(textpunkt1)

# %%
txt = tokens1
score1 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score1 = score1 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score1)
# Out:
# Item score: glatstrik 1
# Item score: bærestykket 1
# Item score: glatstrik 1
# Item score: masker 1
# Item score: rundpinden 1
# Item score: ret 1
# Item score: omg 1
# Item score: vrang 1
# Item score: omg 1
# Item score: ret 1
# Item score: markør 1
# Item score: maske 1
# Item score: markører 1
# Item score: bærestykke 1
# Item score: bærestykket 1
# Item score: glatstrik 1
# Item score: ret 1
# Item score: m 1
# Item score: m 1
# Item score: masker 1
# Item score: ret 1
# Item score: omslag 2
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: ret 1
# Item score: ret 1
# Item score: m 1
# Item score: masker 1
# Item score: ret 1
# Item score: omslag 2
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: maske 1
# Item score: omslaget 2
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# ...

# %%
RettetScore1=score1/AntalTegn1*100
RettetScore1
# Out:
# 3.6684782608695654

# %%
# Ballet_blusen

# %%
text_Ballet= 'Nemme/Ballet_blusen.txt'

with open(text_Ballet, encoding="utf8") as f:
    Ballet_str = f.read()

f.close()

# %%
text_lower2 = Ballet_str.lower()

# %%
textpunkt2 = text_lower2.replace("."," ")

# %%
AntalTegn2 = len(textpunkt2)

# %%
AntalTegn2
# Out:
# 3092

# %%
tokens2=nltk.word_tokenize(textpunkt2)

# %%
txt = tokens2
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score2 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score2 = score2 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score2)
# Out:
# Item score: m 1
# Item score: glatstrik 1
# Item score: kantmasker 1
# Item score: ret 1
# Item score: masker 1
# Item score: vr 1
# Item score: vr 1
# Item score: m 1
# Item score: p 1
# Item score: vr 1
# Item score: vrang 1
# Item score: p 1
# Item score: indtagninger 2
# Item score: kantmaske 1
# Item score: ret 1
# Item score: ret 1
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: maske 1
# Item score: kantmaske 1
# Item score: m 1
# Item score: bagstykke 1
# Item score: m 1
# Item score: forstykke 1
# Item score: m 1
# Item score: forstykke 1
# Item score: masker 1
# Item score: ret 1
# Item score: m 1
# Item score: ret 1
# Item score: indtagning 2
# Item score: forstykke 1
# Item score: ret 1
# Item score: ret 1
# Item score: m 1
# Item score: bagstykke 1
# Item score: masker 1
# Item score: maske 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: p 1
# Item score: vrang 1
# Item score: masker 1
# ...

# %%
RettetScore2=score2/AntalTegn2*100
RettetScore2
# Out:
# 2.554980595084088

# %%
# Blueberry_cream_sweater

# %%
text_Blueberry= 'Nemme/Blueberry_cream_sweater.txt'

with open(text_Blueberry, encoding="utf8") as f:
    Blueberry_str = f.read()

f.close()

# %%
text_lower3 = Blueberry_str.lower()

# %%
textpunkt3 = text_lower3.replace("."," ")

# %%
AntalTegn3 = len(textpunkt3)

# %%
AntalTegn3
# Out:
# 6247

# %%
tokens3=nltk.word_tokenize(textpunkt3)

# %%
txt = tokens3
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score3 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score3 = score3 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score3)
# Out:
# Item score: raglan 2
# Item score: maske 1
# Item score: maske 1
# Item score: ret 1
# Item score: masker 1
# Item score: maske 1
# Item score: omslagene 2
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: masker 1
# Item score: ret 1
# Item score: ret 1
# Item score: masker 1
# Item score: maske 1
# Item score: ret 1
# Item score: ret 1
# Item score: maske 1
# Item score: masken 1
# Item score: bærestykke 1
# Item score: rundpind 1
# Item score: bærestykket 1
# Item score: ryg 1
# Item score: forstykke 1
# Item score: forstykke 1
# Item score: rundpind 1
# Item score: rundpind 1
# Item score: strømpepinde 2
# Item score: masker 1
# Item score: rundpind 1
# Item score: rundpind 1
# Item score: rundpind 1
# Item score: maskerne 1
# Item score: rundpind 1
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: ribben 2
# Item score: rib 2
# Item score: maske 1
# Item score: maske 1
# Item score: rundpind 1
# ...

# %%
RettetScore3=score3/AntalTegn3*100
RettetScore3
# Out:
# 2.593244757483592

# %%
# Bluse_med_kontrastkanter

# %%
text_Bluse_med_kontrastkanter= 'Nemme/Bluse_med_kontrastkanter.txt'

with open(text_Bluse_med_kontrastkanter, encoding="utf8") as f:
    Bluse_med_kontrastkanter_str = f.read()

f.close()

# %%
text_lower4 = Bluse_med_kontrastkanter_str.lower()

# %%
textpunkt4 = text_lower4.replace("."," ")

# %%
AntalTegn4 = len(textpunkt4)

# %%
AntalTegn4
# Out:
# 1825

# %%
tokens4=nltk.word_tokenize(textpunkt4)

# %%
txt = tokens4
            score4 = score4 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score4)
# Out:
# Item score: m 1
# Item score: rundp 1
# Item score: rundp 1
# Item score: rib 2
# Item score: r 1
# Item score: vr 1
# Item score: fv 1
# Item score: rundp 1
# Item score: maskerne 1
# Item score: markør 1
# Item score: m 1
# Item score: m 1
# Item score: markør 1
# Item score: m 1
# Item score: m 1
# Item score: markør 1
# Item score: m 1
# Item score: m 1
# Item score: markør 1
# Item score: m 1
# Item score: m 1
# Item score: m 1
# Item score: udt 1
# Item score: raglan 2
# Item score: m 1
# Item score: m 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: r 1
# Item score: m 1
# Item score: omg 1
# Item score: omg 1
# Item score: m 1
# Item score: arb 1
# Item score: m 1
# Item score: m 1
# Item score: m 1
# Item score: m 1
# Item score: m 1
# Item score: arb 1
# Item score: ærmegab 1
# Item score: ribkant 2
# Item score: rundp 1
# Item score: rib 2
# Item score: r 1
# Item score: vr 1
# Item score: aflukning 1
# Item score: m 1
# Item score: omg 1
# ...

# %%
RettetScore4=score4/AntalTegn4*100
RettetScore4
# Out:
# 3.9452054794520546

# %%
# Bluse_med_lange_masker

# %%
text_Bluse_med_lange_masker= 'Nemme/Bluse_med_lange_masker.txt'

with open(text_Bluse_med_lange_masker, encoding="utf8") as f:
    Bluse_med_lange_masker_str = f.read()

f.close()

# %%
text_lower5 = Bluse_med_lange_masker_str.lower()

# %%
textpunkt5 = text_lower5.replace("."," ")

# %%
AntalTegn5 = len(textpunkt5)

# %%
AntalTegn5
# Out:
# 3450

# %%
tokens5=nltk.word_tokenize(textpunkt5)

# %%
txt = tokens5
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score5 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score5 = score5 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score5)
# Out:
# Item score: masker 1
# Item score: masker 1
# Item score: m 1
# Item score: omg 1
# Item score: omg 1
# Item score: m 1
# Item score: r 1
# Item score: omg 1
# Item score: omg 1
# Item score: m 1
# Item score: r 1
# Item score: omslagene 2
# Item score: omg 1
# Item score: p 1
# Item score: bærestykke 1
# Item score: m 1
# Item score: rundp 1
# Item score: rib 2
# Item score: r 1
# Item score: vr 1
# Item score: rundp 1
# Item score: omg 1
# Item score: m 1
# Item score: m 1
# Item score: p 1
# Item score: r 1
# Item score: gent 1
# Item score: m 1
# Item score: p 1
# Item score: r 1
# Item score: gent 1
# Item score: m 1
# Item score: p 1
# Item score: r 1
# Item score: gent 1
# Item score: r 1
# Item score: m 1
# Item score: omg 1
# Item score: r 1
# Item score: omslag 2
# Item score: omg 1
# Item score: p 1
# Item score: omg 1
# Item score: vr 1
# Item score: omg 1
# Item score: r 1
# Item score: omg 1
# Item score: vr 1
# Item score: omg 1
# Item score: r 1
# Item score: m 1
# ...

# %%
RettetScore5=score5/AntalTegn5*100
RettetScore5
# Out:
# 4.869565217391305

# %%
# Cassi_cardigan

# %%
text_Cassi_cardigan= 'Nemme/Cassi_cardigan.txt'

with open(text_Cassi_cardigan, encoding="utf8") as f:
    Cassi_cardigan_str = f.read()

f.close()

# %%
text_lower6 = Cassi_cardigan_str.lower()

# %%
textpunkt6 = text_lower6.replace("."," ")

# %%
AntalTegn6 = len(textpunkt6)

# %%
AntalTegn6
# Out:
# 4688

# %%
tokens6=nltk.word_tokenize(textpunkt6)

# %%
txt = tokens6
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score6 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score6 = score6 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score6)
# Out:
# Item score: r 1
# Item score: ret 1
# Item score: vr 1
# Item score: vrang 1
# Item score: omg 1
# Item score: r 1
# Item score: sm 1
# Item score: ret 1
# Item score: mm 1
# Item score: maskemarkør 1
# Item score: lænken 1
# Item score: lænken 1
# Item score: masker 1
# Item score: m 1
# Item score: rundpind 1
# Item score: m 1
# Item score: vrang 1
# Item score: rib 2
# Item score: ret 1
# Item score: m 1
# Item score: ret 1
# Item score: ret 1
# Item score: mønster 3
# Item score: m 1
# Item score: ret 1
# Item score: m 1
# Item score: mønster 3
# Item score: m 1
# Item score: ret 1
# Item score: maskerne 1
# Item score: m 1
# Item score: opslagskanten 1
# Item score: mønster 3
# Item score: kantmaskerne 1
# Item score: maskerne 1
# Item score: raglan 2
# Item score: m 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: markører 1
# Item score: mønster 3
# Item score: m 1
# Item score: mm 1
# Item score: ret 1
# Item score: mm 1
# Item score: ret 1
# ...

# %%
tokens6=nltk.word_tokenize(textpunkt6)

# %%
RettetScore6=score6/AntalTegn6*100
RettetScore6
# Out:
# 4.671501706484642

# %%
# Cherised_moments

# %%
text_Cherised_moments= 'Nemme/Cherised_moments.txt'

with open(text_Cherised_moments, encoding="utf8") as f:
    Cherised_moments_str = f.read()

f.close()

# %%
text_lower7 = Cherised_moments_str.lower()

# %%
textpunkt7 = text_lower7.replace("."," ")

# %%
AntalTegn7 = len(textpunkt7)

# %%
AntalTegn7
# Out:
# 3263

# %%
tokens7=nltk.word_tokenize(textpunkt7)

# %%
txt = tokens7
        if w == k:
            score7 = score7 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score7)
# Out:
# Item score: glatstrik 1
# Item score: ret 1
# Item score: vrang 1
# Item score: bagstykke 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: vrang 1
# Item score: glatstrik 1
# Item score: ret 1
# Item score: forstykke 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: vrang 1
# Item score: glatstrik 1
# Item score: ret 1
# Item score: masker 1
# Item score: masker 1
# Item score: ret 1
# Item score: maske 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: vrang 1
# Item score: ret 1
# Item score: forstykke 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: vrang 1
# Item score: glatstrik 1
# Item score: masker 1
# Item score: ret 1
# Item score: maske 1
# Item score: masken 1
# Item score: ret 1
# Item score: maske 1
# ...

# %%
RettetScore7=score7/AntalTegn7*100
RettetScore7
# Out:
# 2.5436714679742565

# %%
# Colette

# %%
text_Colette= 'Nemme/Colette.txt'

with open(text_Colette, encoding="utf8") as f:
    Colette_str = f.read()

f.close()

# %%
text_lower8 = Colette_str.lower()

# %%
textpunkt8 = text_lower8.replace("."," ")

# %%
AntalTegn8 = len(textpunkt8)

# %%
AntalTegn8
# Out:
# 3343

# %%
tokens8=nltk.word_tokenize(textpunkt8)

# %%
txt = tokens8
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score8 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score8 = score8 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score8)
# Out:
# Item score: masker 1
# Item score: ribkant 2
# Item score: masker 1
# Item score: strømpepind 2
# Item score: mm 1
# Item score: rib 2
# Item score: drejet 2
# Item score: ret 1
# Item score: drejet 2
# Item score: vrang 1
# Item score: strømpepind 2
# Item score: mm 1
# Item score: markør 1
# Item score: glatstrik 1
# Item score: masker 1
# Item score: markøren 1
# Item score: maske 1
# Item score: markøren 1
# Item score: lænken 1
# Item score: drejet 2
# Item score: ret 1
# Item score: ret 1
# Item score: lænken 1
# Item score: drejet 2
# Item score: ret 1
# Item score: ret 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: masker 1
# Item score: vrang 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: masker 1
# Item score: masker 1
# Item score: maske 1
# Item score: markøren 1
# Item score: masker 1
# Item score: forstykke 1
# Item score: bagstykke 1
# Item score: forstykke 1
# ...

# %%
RettetScore8=score8/AntalTegn8*100
RettetScore8
# Out:
# 4.157941968291953

# %%
# Dusky_rose

ersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score9 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score9 = score9 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score9)
# Out:
# Item score: retstrik 1
# Item score: ret 1
# Item score: indtagninger 2
# Item score: maske 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: maske 1
# Item score: ret 1
# Item score: maske 1
# Item score: ret 1
# Item score: ret 1
# Item score: maske 1
# Item score: masken 1
# Item score: maske 1
# Item score: maske 1
# Item score: masker 1
# Item score: masker 1
# Item score: ret 1
# Item score: maske 1
# Item score: maske 1
# Item score: ret 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: masker 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: omslagene 2
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: rundpind 1
# Item score: strømpepinde 2
# Item score: rundpind 1
# Item score: bagstykke 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: ret 1
# Item score: rib 2
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: maske 1
# ...

# %%
RettetScore9=score9/AntalTegn9*100
RettetScore9
# Out:
# 2.8582615505090057

# %%
# Eva_sweater

# %%
text_Eva_sweater= 'Nemme/Eva_sweater.txt'

with open(text_Eva_sweater, encoding="utf8") as f:
    Eva_sweater_str = f.read()

f.close()

# %%
text_lower10 = Eva_sweater_str.lower()

# %%
textpunkt10 = text_lower10.replace("."," ")

# %%
AntalTegn10 = len(textpunkt10)

# %%
AntalTegn10
# Out:
# 3518

# %%
tokens10=nltk.word_tokenize(textpunkt10)

# %%
txt = tokens10
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslag
# Item score: km 1
# Item score: kantmaske 1
# Item score: arb 1
# Item score: p 1
# Item score: rts 1
# Item score: omg 1
# Item score: fv 1
# Item score: bærestykke 1
# Item score: rundpind 1
# Item score: m 1
# Item score: omg 1
# Item score: ret 1
# Item score: m 1
# Item score: drejet 2
# Item score: ret 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: m 1
# Item score: arb 1
# Item score: omg 1
# Item score: ret 1
# Item score: m 1
# Item score: m 1
# Item score: arb 1
# Item score: omg 1
# Item score: ret 1
# Item score: m 1
# Item score: m 1
# Item score: arb 1
# Item score: omg 1
# Item score: ret 1
# Item score: m 1
# Item score: m 1
# Item score: arb 1
# Item score: omg 1
# Item score: m 1
# Item score: m 1
# Item score: m 1
# Item score: ryg 1
# ...

# %%
RettetScore10=score10/AntalTegn10*100
RettetScore10
# Out:
# 3.069926094371802

# %%
# Evelyn_top_down_cardigan

# %%
text_Evelyn_cardigan= 'Nemme/Evelyn_top_down_cardigan.txt'

with open(text_Evelyn_cardigan, encoding="utf8") as f:
    Evelyn_cardigan_str = f.read()

f.close()

# %%
text_lower11 = Evelyn_cardigan_str.lower()

# %%
textpunkt11 = text_lower11.replace("."," ")

# %%
AntalTegn11 = len(textpunkt11)

# %%
AntalTegn11
# Out:
# 8164

# %%
tokens11=nltk.word_tokenize(textpunkt11)

# %%
txt = tokens11
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score11 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score11 = score11 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score11)
# Out:
# Item score: ret 1
# Item score: vrang 1
# Item score: ret 1
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: m 1
# Item score: m 1
# Item score: markør 1
# Item score: m 1
# Item score: ret 1
# Item score: masken 1
# Item score: masken 1
# Item score: m 1
# Item score: markøren 1
# Item score: ret 1
# Item score: m 1
# Item score: m 1
# Item score: markør 1
# Item score: m 1
# Item score: markøren 1
# Item score: ret 1
# Item score: masken 1
# Item score: masken 1
# Item score: ret 1
# Item score: raglan 2
# Item score: ryg 1
# Item score: forstykke 1
# Item score: masker 1
# Item score: vrang 1
# Item score: maskemarkører 1
# Item score: m 1
# Item score: mm 1
# Item score: m 1
# Item score: mm 1
# Item score: m 1
# Item score: mm 1
# Item score: m 1
# Item score: mm 1
# Item score: m 1
# Item score: raglan 2
# Item score: raglan 2
# Item score: m 1
# Item score: forstykke 1
# Item score: m 1
# Item score: ret 1
# Item score: drejet 2
# Item score: ret 1
# ...

# %%
RettetScore11=score11/AntalTegn11*100
RettetScore11
# Out:
# 4.042136207741303

# %%
# Full_moon_romance

# %%
text_Full_moon= 'Nemme/Full_moon_romance.txt'

with open(text_Full_moon, encoding="utf8") as f:
ene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score12 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score12 = score12 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score12)
# Out:
# Item score: retstrik 1
# Item score: ret 1
# Item score: masker 1
# Item score: kantmaskerne 1
# Item score: masker 1
# Item score: masker 1
# Item score: indtagninger 2
# Item score: maske 1
# Item score: maske 1
# Item score: ret 1
# Item score: ærmegab 1
# Item score: indtagninger 2
# Item score: masker 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: masker 1
# Item score: ret 1
# Item score: maske 1
# Item score: ret 1
# Item score: ret 1
# Item score: maske 1
# Item score: maskerne 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: ret 1
# Item score: maske 1
# Item score: masker 1
# Item score: ret 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: maske 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: masker 1
# Item score: ret 1
# Item score: maske 1
# Item score: ret 1
# Item score: ret 1
# Item score: maske 1
# Item score: masken 1
# Item score: maske 1
# Item score: masker 1
# ...

# %%
RettetScore12=score12/AntalTegn12*100
RettetScore12
# Out:
# 3.0306733471831846

# %%
# Good_old_raglan

# %%
text_Good_old_raglan= 'Nemme/Good_old_raglan.txt'

with open(text_Good_old_raglan, encoding="utf8") as f:
    Good_old_raglan_str = f.read()

f.close()

# %%
text_lower13 = Good_old_raglan_str.lower()

# %%
textpunkt13 = text_lower13.replace("."," ")

# %%
AntalTegn13 = len(textpunkt13)

# %%
AntalTegn13
# Out:
# 8491

# %%
tokens13=nltk.word_tokenize(textpunkt13)

# %%
txt = tokens13
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score13 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score13 = score13 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score13)
# Out:
# Item score: raglan 2
# Item score: raglan 2
# Item score: vendepinde 3
# Item score: bærestykket 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: ribkanter 2
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: glatstrik 1
# Item score: ret 1
# Item score: glatstrik 1
# Item score: ret 1
# Item score: vrang 1
# Item score: vendepinde 3
# Item score: vendepinde 3
# Item score: vendepinde 3
# Item score: lænken 1
# Item score: maskerne 1
# Item score: ret 1
# Item score: lænken 1
# Item score: maske 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: vrang 1
# Item score: lænken 1
# Item score: maske 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: ret 1
# Item score: lænken 1
# Item score: maske 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: vrang 1
# Item score: lænken 1
# Item score: maske 1
# Item score: indtagninger 2
# Item score: r 1
# Item score: sm 1
# Item score: masker 1
# Item score: ret 1
# ...

# %%
RettetScore13=score13/AntalTegn13*100
RettetScore13
# Out:
# 2.4496525733129193

# %%
# Herresweater_sort_blå_hvid

# %%
text_Herresweater_sort_blå_hvid= 'Nemme/Herresweater_sort_blå_hvid.txt'

with open(text_Herresweater_sort_blå_hvid, encoding="utf8") as f:
    Herresweater_sort_blå_hvid_str = f.read()

f.close()

# %%
text_lower14 = Herresweater_sort_blå_hvid_str.lower()

# %%
textpunkt14 = text_lower14.replace("."," ")

# %%
AntalTegn14 = len(textpunkt14)

# %%
AntalTegn14
# Out:
# 3122

# %%
tokens14=nltk.word_tokenize(textpunkt14)

# %%
txt = tokens14
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score14 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score14 = score14 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score14)
# Out:
# Item score: ribkanter 2
# Item score: ryg 1
# Item score: forstykke 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: maske 1
# Item score: forstykke 1
# Item score: ryg 1
# Item score: masker 1
# Item score: ret 1
# Item score: vrang 1
# Item score: ryg 1
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: masker 1
# Item score: drejet 2
# Item score: ret 1
# Item score: ret 1
# Item score: vrang 1
# Item score: indtagninger 2
# Item score: ærmegabet 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: forstykke 1
# Item score: ærmegabet 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: ærmegabet 1
# Item score: masker 1
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: masker 1
# Item score: maske 1
# Item score: masker 1
# Item score: ryg 1
# Item score: ærmegabet 1
# ...

# %%
RettetScore14=score14/AntalTegn14*100
RettetScore14
# Out:
# 2.0179372197309418

# %%
# Junesweater

# %%
text_Junesweater= 'Nemme/Junesweater.txt'

with open(text_Junesweater, encoding="utf8") as f:
    Junesweater_str = f.read()

f.close()

# %%
text_lower15 = Junesweater_str.lower()

# %%
textpunkt15 = text_lower15.replace("."," ")

er":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score15 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score15 = score15 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score15)
# Out:
# Item score: m 1
# Item score: maske 1
# Item score: r 1
# Item score: ret 1
# Item score: vr 1
# Item score: vrang 1
# Item score: sm 1
# Item score: mm 1
# Item score: maskemarkør 1
# Item score: km 1
# Item score: kantmaske 1
# Item score: arb 1
# Item score: p 1
# Item score: rts 1
# Item score: omg 1
# Item score: fv 1
# Item score: ryg 1
# Item score: forstykke 1
# Item score: m 1
# Item score: rundp 1
# Item score: maskerne 1
# Item score: m 1
# Item score: maskeholder 2
# Item score: ærmegabet 1
# Item score: maskerne 1
# Item score: m 1
# Item score: ribben 2
# Item score: ret 1
# Item score: vrang 1
# Item score: strømpepinde 2
# Item score: m 1
# Item score: maske 1
# Item score: m 1
# Item score: m 1
# Item score: m 1
# Item score: m 1
# Item score: rundpind 1
# Item score: montering 3
# Item score: bagstykke 1
# Samlet score:  44

# %%
RettetScore15=score15/AntalTegn15*100
RettetScore15
# Out:
# 3.725656223539373

# %%
# Melody_bluse

# %%
text_Melody_bluse= 'Nemme/Melody_bluse.txt'

with open(text_Melody_bluse, encoding="utf8") as f:
    Melody_bluse_str = f.read()

f.close()

# %%
text_lower16 = Melody_bluse_str.lower()

# %%
textpunkt16 = text_lower16.replace("."," ")

# %%
AntalTegn16 = len(textpunkt16)

# %%
AntalTegn16
# Out:
# 2874

# %%
tokens16=nltk.word_tokenize(textpunkt16)

# %%
txt = tokens16
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score16 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score16 = score16 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score16)
# Out:
# Item score: masker 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: rib 2
# Item score: drejet 2
# Item score: ret 1
# Item score: vrang 1
# Item score: bærestykke 1
# Item score: maskerne 1
# Item score: markør 1
# Item score: maske 1
# Item score: masker 1
# Item score: markør 1
# Item score: maske 1
# Item score: masker 1
# Item score: markør 1
# Item score: maske 1
# Item score: masker 1
# Item score: markør 1
# Item score: maske 1
# Item score: masker 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: raglan 2
# Item score: glatstrik 1
# Item score: maske 1
# Item score: masker 1
# Item score: lænken 1
# Item score: maskerne 1
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: raglan 2
# Item score: masker 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: rundpind 1
# ...

# %%
RettetScore16=score16/AntalTegn16*100
RettetScore16
# Out:
# 3.2011134307585247

# %%
# Newbie_sweater

# %%
text_Newbie_sweater= 'Nemme/Newbie_sweater.txt'

with open(text_Newbie_sweater, encoding="utf8") as f:
    Newbie_sweater_str = f.read()

f.close()

# %%
text_lower17 = Newbie_sweater_str.lower()

# %%
textpunkt17 = text_lower17.replace("."," ")

# %%
AntalTegn17 = len(textpunkt17)

# %%
AntalTegn17
# Out:
# 2013

# %%
tokens17=nltk.word_tokenize(textpunkt17)

# %%
txt = tokens17
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score17 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score17 = score17 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score17)
# Out:
# Item score: bagstykke 1
# Item score: rundpind 1
# Item score: m 1
# Item score: mm 1
# Item score: rib 2
# Item score: r 1
# Item score: vr 1
# Item score: glatstrik 1
# Item score: r 1
# Item score: vr 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: m 1
# Item score: mm 1
# Item score: rib 2
# Item score: r 1
# Item score: vr 1
# Item score: mm 1
# Item score: glatstrik 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: fv 1
# Item score: montering 3
# Item score: skuldersømmen 3
# Item score: bagstykke 1
# Item score: skuldersømmen 3
# Samlet score:  47

# %%
RettetScore17=score17/AntalTegn17*100
RettetScore17
# Out:
# 2.334823646299056

# %%
# Nina_sweater

# %%
text_Nina_sweater= 'Nemme/Nina_sweater.txt'

with open(text_Nina_sweater, encoding="utf8") as f:
    Nina_sweater_str = f.read()

f.close()

# %%
text_lower18 = Nina_sweater_str.lower()

# %%
textpunkt18 = text_lower18.replace("."," ")

# %%
AntalTegn18 = len(textpunkt18)

# %%
AntalTegn18
# Out:
# 6069

# %%
tokens18=nltk.word_tokenize(textpunkt18)

# %%
txt = tokens18
score18 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score18 = score18 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score18)
# Out:
# Item score: omslag 2
# Item score: hulmønster 3
# Item score: m 1
# Item score: maske 1
# Item score: r 1
# Item score: ret 1
# Item score: vr 1
# Item score: vrang 1
# Item score: sm 1
# Item score: mm 1
# Item score: maskemarkør 1
# Item score: km 1
# Item score: kantmaske 1
# Item score: arb 1
# Item score: p 1
# Item score: rts 1
# Item score: omg 1
# Item score: fv 1
# Item score: glatstrik 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: vrang 1
# Item score: maske 1
# Item score: lænken 1
# Item score: ret 1
# Item score: maske 1
# Item score: lænken 1
# Item score: drejet 2
# Item score: ret 1
# Item score: bærestykke 1
# Item score: m 1
# Item score: mm 1
# Item score: masker 1
# Item score: ret 1
# Item score: vrang 1
# Item score: bærestykket 1
# Item score: omslag 2
# Item score: m 1
# Item score: r 1
# Item score: m 1
# Item score: m 1
# Item score: forstykke 1
# Item score: markør 1
# Item score: markør 1
# Item score: m 1
# ...

# %%
RettetScore18=score18/AntalTegn18*100
RettetScore18
# Out:
# 2.932937881034767

# %%
# Pepita_cardigan

# %%
text_Pepita_cardigan= 'Nemme/Pepita_cardigan.txt'

with open(text_Pepita_cardigan, encoding="utf8") as f:
    Pepita_cardigan_str = f.read()

f.close()

# %%
text_lower19 = Pepita_cardigan_str.lower()

# %%
textpunkt19 = text_lower19.replace("."," ")

# %%
AntalTegn19 = len(textpunkt19)

# %%
AntalTegn19
# Out:
# 5681

# %%
textpunkt19
# Out:
# 'pepita top-down cardigan med rund hals i mayflower cotton merino solid \n\nglat: ret på retsiden, vrang på vrangsiden / ret på alle omgange \ndobbelt rib: skiftevis 2 ret og 2 vrang \nkantmaske (km): den 1  maske på alle pinde tages ret løs af og den sidste maske strikkes ret \nder begyndes med ryggen, som strikkes frem og tilbage ned til afslutningen på ærmegabene  \nforstykkerne strikkes på fra ryggens skuldermasker og strikkes hver for sig frem og tilbage til afslutningen på ærmegabene  derefter strikkes kroppen samlet frem og tilbage og sluttes med kanten forneden  ærmerne strikkes på og til slut strikkes halskant og forkanter \n\nryg \nslå 78(82)86(92)96(100) masker op på p nr  3½ og strik 1 pind vrang, idet der samtidig sættes en\nmaskemarkør (ikke på pinden, men i opslagningskanten) på hver side af de midterste 36(38)40(42) 44(46)\nmasker til hals  det giver 21(22)23(25)26(27) masker i hver side til skuldre \nfra den følgende retsidepind strikkes vendepinde over skuldermasker
# ...

# %%
tokens19=nltk.word_tokenize(textpunkt19)

# %%
txt = tokens19
        if w == k:
            score19 = score19 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score19)
# Out:
# Item score: ret 1
# Item score: vrang 1
# Item score: ret 1
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: kantmaske 1
# Item score: km 1
# Item score: maske 1
# Item score: ret 1
# Item score: maske 1
# Item score: ret 1
# Item score: ryg 1
# Item score: masker 1
# Item score: p 1
# Item score: vrang 1
# Item score: maskemarkør 1
# Item score: masker 1
# Item score: masker 1
# Item score: retsidepind 3
# Item score: vendepinde 3
# Item score: markør 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: retsidepind 3
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: omslaget 2
# Item score: ret 1
# Item score: maske 1
# Item score: masker 1
# Item score: vrang 1
# Item score: vrang 1
# Item score: vrang 1
# Item score: omslaget 2
# Item score: drejet 2
# Item score: vrang 1
# Item score: maske 1
# Item score: vrang 1
# Item score: ret 1
# ...

# %%
RettetScore19=score19/AntalTegn19*100
RettetScore19
# Out:
# 3.4853018834712204

# %%
# Rhytmic_rain

# %%
text_Rhythmic_rain= 'Nemme/Rhythmic_rain.txt'

with open(text_Rhythmic_rain, encoding="utf8") as f:
    Rhythmic_rain_str = f.read()

f.close()

# %%
text_lower20 = Rhythmic_rain_str.lower()

# %%
textpunkt20 = text_lower20.replace("."," ")

# %%
AntalTegn20 = len(textpunkt20)

# %%
AntalTegn20
# Out:
# 5682

# %%
tokens20=nltk.word_tokenize(textpunkt20)

# %%
txt = tokens20
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score20 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score20 = score20 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score20)
# Out:
# Item score: retstrik 1
# Item score: ret 1
# Item score: masker 1
# Item score: maske 1
# Item score: omslagene 2
# Item score: drejet 2
# Item score: maske 1
# Item score: masker 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: maske 1
# Item score: ret 1
# Item score: ret 1
# Item score: maske 1
# Item score: masken 1
# Item score: masker 1
# Item score: omslag 2
# Item score: maske 1
# Item score: omslagene 2
# Item score: masker 1
# Item score: bærestykket 1
# Item score: rundpind 1
# Item score: ribben 2
# Item score: glatstrik 1
# Item score: bærestykket 1
# Item score: ryg 1
# Item score: forstykke 1
# Item score: forstykke 1
# Item score: rundpind 1
# Item score: forstykke 1
# Item score: bagstykke 1
# Item score: rundpind 1
# Item score: rundpind 1
# Item score: strømpepinde 2
# Item score: masker 1
# Item score: rundpind 1
# Item score: ret 1
# Item score: rib 2
# Item score: ret 1
# ...

# %%
RettetScore20=score20/AntalTegn20*100
RettetScore20
# Out:
# 2.815909890883492

# %%
# Serene_forest

# %%
text_Serene_forest= 'Nemme/Serene_forest.txt'

with open(text_Serene_forest, encoding="utf8") as f:
    Serene_forest_str = f.read()

f.close()

# %%
text_lower21 = Serene_forest_str.lower()

# %%
textpunkt21 = text_lower21.replace("."," ")

# %%
AntalTegn21 = len(textpunkt21)

# %%
AntalTegn21
# Out:
# 4609

# %%
tokens21=nltk.word_tokenize(textpunkt21)

# %%
txt = tokens21
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score21 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score21 = score21 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score21)
# Out:
# Item score: masker 1
# Item score: masker 1
# Item score: ret 1
# Item score: masker 1
# Item score: omslagene 2
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: ærmekuppel 3
# Item score: ryg 1
# Item score: forstykke 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: ret 1
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: rib 2
# Item score: rundpind 1
# Item score: glatstrik 1
# Item score: masker 1
# Item score: ærmegab 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: bagstykke 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: ærmegab 1
# Item score: masker 1
# Item score: maske 1
# Item score: masker 1
# Item score: masker 1
# Item score: maske 1
# Item score: masker 1
# Item score: glatstrik 1
# Item score: ærmegab 1
# ...

# %%
RettetScore21=score21/AntalTegn21*100
RettetScore21
# Out:
# 2.5385116077240184

# %%
# Sweater_no9

# %%
text_Sweater_no9= 'Nemme/Sweater_no9.txt'

with open(text_Sweater_no9, encoding="utf8") as f:
    Sweater_no9_str = f.read()

f.close()

# %%
text_lower22 = Sweater_no9_str.lower()

# %%
textpunkt22 = text_lower22.replace("."," ")

# %%
AntalTegn22 = len(textpunkt22)

# %%
AntalTegn22
# Out:
# 8724

# %%
tokens22=nltk.word_tokenize(textpunkt22)

# %%
txt = tokens22
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "afl
# Item score: lænken 1
# Item score: maskemarkør 1
# Item score: lænken 1
# Item score: ret 1
# Item score: markøren 1
# Item score: lænken 1
# Item score: markøren 1
# Item score: drejet 2
# Item score: ret 1
# Item score: rib 2
# Item score: rib 2
# Item score: ribben 2
# Item score: ret 1
# Item score: vrang 1
# Item score: rundpind 1
# Item score: masker 1
# Item score: indtagninger 2
# Item score: indtagninger 2
# Item score: ret 1
# Item score: drejet 2
# Item score: ret 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: mm 1
# Item score: masker 1
# Item score: rib 2
# Item score: maskemarkør 1
# Item score: markøren 1
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: bærestykket 1
# Item score: maskemarkører 1
# Item score: markørerne 1
# Item score: bærestykke 1
# ...

# %%
RettetScore22=score22/AntalTegn22*100
RettetScore22
# Out:
# 2.613480055020633

# %%
# Thea_top

# %%
text_Thea_top= 'Nemme/Thea_top.txt'

with open(text_Thea_top, encoding="utf8") as f:
    Thea_top_str = f.read()

f.close()

# %%
text_lower23 = Thea_top_str.lower()

# %%
textpunkt23 = text_lower23.replace("."," ")

# %%
AntalTegn23 = len(textpunkt23)

# %%
AntalTegn23
# Out:
# 2557

# %%
tokens23=nltk.word_tokenize(textpunkt23)

# %%
txt = tokens23
allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score23 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score23 = score23 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score23)
# Out:
# Item score: glatstrik 1
# Item score: rundpind 1
# Item score: ærmegabet 1
# Item score: maske 1
# Item score: m 1
# Item score: maske 1
# Item score: r 1
# Item score: ret 1
# Item score: vr 1
# Item score: vrang 1
# Item score: sm 1
# Item score: mm 1
# Item score: maskemarkør 1
# Item score: km 1
# Item score: kantmaske 1
# Item score: arb 1
# Item score: p 1
# Item score: rts 1
# Item score: omg 1
# Item score: fv 1
# Item score: fv 1
# Item score: p 1
# Item score: fv 1
# Item score: p 1
# Item score: rundpind 1
# Item score: fv 1
# Item score: masker 1
# Item score: ret 1
# Item score: rib 2
# Item score: ret 1
# Item score: vrang 1
# Item score: p 1
# Item score: glatstrik 1
# Item score: fv 1
# Item score: ærmegabet 1
# Item score: masker 1
# Item score: aflukningerne 1
# Item score: masker 1
# Item score: masker 1
# Item score: masker 1
# Item score: skulderaflukninger 3
# Item score: masker 1
# Item score: masker 1
# Item score: skulderaflukninger 3
# Item score: masker 1
# ...

# %%
RettetScore23=score23/AntalTegn23*100
RettetScore23
# Out:
# 2.4247164646069614

# %%
# Violet_meadow

# %%
text_Violet_meadow= 'Nemme/Violet_meadow.txt'

with open(text_Violet_meadow, encoding="utf8") as f:
    Violet_meadow_str = f.read()

f.close()

# %%
inden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score24 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score24 = score24 + v
            print("Item score:", k, v)
            
print("Samlet score: ", score24)
# Out:
# Item score: retstrik 1
# Item score: ret 1
# Item score: mønster 3
# Item score: diagram 3
# Item score: mønsteret 3
# Item score: rundpind 1
# Item score: bagstykke 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: vrang 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: ret 1
# Item score: vrang 1
# Item score: masker 1
# Item score: ret 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: ribben 2
# Item score: ret 1
# Item score: masker 1
# Item score: masker 1
# Item score: ret 1
# Item score: rundpind 1
# Item score: glatstrik 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: ærmegab 1
# Item score: masker 1
# Item score: masker 1
# Item score: maske 1
# Item score: masker 1
# Item score: masker 1
# Item score: maske 1
# Item score: masker 1
# Item score: forstykke 1
# Item score: masker 1
# Item score: rundpind 1
# Item score: vrang 1
# Item score: kantmaske 1
# Item score: retstrik 1
# Item score: vrang 1
# ...

# %%
RettetScore24=score24/AntalTegn24*100
RettetScore24
# Out:
# 3.263681592039801

# %%
samlede_middel0 = []

path = os.path.join("Middel")

for fil in os.scandir(path):
    with open (fil, encoding = "utf8") as f:
        samlede_middel0.append(f.read())

# %%
samlede_middel0
# Out:
# ["\ufeffBasket Weave - en herresweater med strukturmønster\n\nRyg/forstykke:\nSlå 104 (112) 120 (128) m op og strik rundt i rib, 2\nret, 2 vrang. Strik i alt 15 omg og skift herefter til\nglatstrikning. Sæt et mærke i hver side af arbejdet\ndvs. ved omg's begyndelse og mellem de to midterste\nm. Strik 9 omg og tag på næste omg ud således: *1\nret, 1 udt, strik til 1 m før næste mærke, 1 udt, 1\nret*, gentag fra * til * yderligere 1 gang = 4\nudtagning på omg. Gentag udtagningerne på hver 12.\nomg yderligere 3 gange =120 (128) 136 (144) m.\nNår arbejdet måler 40 (40) 42 (44) cm sættes 6 m i\nhver side på en tråd, 3 m på hver side af mærket.\nDer er 54 (58) 62 (66) m på henholdsvis ryg og\nforstykke.Lad arbejdet hvile.\n\nÆrmer:\nSlå 28 (28) 32 (32) m op på strømpepinde og strik\nrundt i rib, 2 ret, 2 vrang. Strik i alt 15 omg og skift\nherefter til glatstrikning. Sæt et mærke ved omg's\nbegyndelse og tag 1 m ud på hver side af mærket\nsåledes: 1 ret, 1 udt strik til 1 m før mærket, 1 
# ...

# %%
samlede_middel1= "".join(samlede_middel0)

# %%
type(samlede_middel1)
# Out:
# str

# %%
text_lower_middel = samlede_middel1.lower()

# %%
samlede_middel2 = text_lower_middel.replace("."," ")

# %%
AntalTegnMiddel = len(samlede_middel2)

# %%
AntalTegnMiddel
# Out:
# 100909

# %%
tokens_middel2=nltk.word_tokenize(samlede_middel2)

# %%
txt = tokens_middel2
bestemtestrikkeord_dictionary={"kantmasken":1,"kantmaskerne":1, "rundpinden":1, "rundpindene":1, "bærestykket":1, "masken":1, "maskerne":1, "ærmegabet":1, "maskemarkøren":1, "maskemarkørerne":1, "markøren":1, "markørerne":1, "aflukningen":1, "aflukningerne":1, "opslagskanten":1, "opslagskanterne":1, "lænken":1, "lænkerne":1, "knaphullet":1, "knaphullerne":1, "strømpepinden":1, "strømpepinde":1,"strømpepindene":1, "omslaget":1, "omslagene":1, "indtagningen":1, "indtagninggerne":1, "ribben":1, "ribkanten":1, "ribkanterne":1, "rillekanten":1, "rillekanterne":1, "raglanen":1, "raglansømmene":1, "sømmene":1, "mærketråden":1, "mærketrådene":1, "retsidepinden":1, "retsidepindene":1, "maskeholderen":1, "maskeholderne":1, "løkkeopslaget":1, "løkkeopslagene":1, "blokken":1, "blokkene":1, "mønsteret":1,  "mønstrene":1, "ærmekuppelen":1, "ærmekuplerne":1, "vendepinden":1, "vendepindene":1, "boblen":1, "boblerne":1,   "skulderaflukningen":1, "skuldersømmen":1, "skuldersømmene":1, "retsidepinden":1, "retsidepindene":1, "elastikken":1, "elastikkerne":1, "elastiksnoren":1, "elastiksnorer":1, "elastiksnorene":1, "sildebensmønsteret":1, "overtræksindtagningen":1, "sidesømsmarkøren":1, "sidesømsmarkørene":1, "ærmesømmen":1, "ærmesømmene":1, "raglanindtagningen":1, "raglanindtagningerne":1}
score_middel = 0

for w in txt:
    for k, v in bestemtestrikkeord_dictionary.items():
        if w == k:
            score_middel = score_middel + v
            print("Item score:", k, v)
            
print("Samlet score: ", score_middel)
# Out:
# Item score: strømpepinde 1
# Item score: mærketråden 1
# Item score: mærketråden 1
# Item score: omslagene 1
# Item score: ærmegabet 1
# Item score: strømpepinde 1
# Item score: maskerne 1
# Item score: maskerne 1
# Item score: maskerne 1
# Item score: strømpepinde 1
# Item score: strømpepinde 1
# Item score: strømpepinde 1
# Item score: mærketråden 1
# Item score: skuldersømmene 1
# Item score: ærmegabet 1
# Item score: ærmegabet 1
# Item score: ærmegabet 1
# Item score: masken 1
# Item score: masken 1
# Item score: maskerne 1
# Item score: omslaget 1
# Item score: mærketråden 1
# Item score: mærketråden 1
# Item score: mærketråden 1
# Item score: masken 1
# Item score: omslagene 1
# Item score: strømpepinde 1
# Item score: mærketråden 1
# Item score: ribben 1
# Item score: strømpepinde 1
# Item score: mærketråden 1
# Item score: mærketråden 1
# Item score: strømpepinde 1
# Item score: ribben 1
# Item score: omslagene 1
# Item score: omslaget 1
# Item score: omslaget 1
# ...

# %%
txt=tokens_middel
allestrikkeord_dictionary={"ret":"Nem", "vrang":"Nem", "retmaske":"Nem", "vrangmaske":"Nem", "retstrik":"Nem", "glatstrik":"Nem", "kantmaske":"Nem", "kantmasken":"Nem", "kantmasker":"Nem", "kantmaskerne":"Nem", "løkkeopslag":"Nem", "rundpind":"Nem", "rundpinden":"Nem", "rundpinde":"Nem", "rundpindene":"Nem", "bærestykke":"Nem", "bærestykket":"Nem", "maske":"Nem", "masken":"Nem", "masker":"Nem", "maskerne":"Nem", "ærmegab":"Nem", "ærmegabet":"Nem", "maskemarkør":"Nem", "maskemarkøren":"Nem", "maskemarkører":"Nem", "maskemarkørerne":"Nem", "markør":"Nem", "markøren":"Nem", "markører":"Nem", "markørerne":"Nem", "aflukning":"Nem", "aflukningen":"Nem", "aflukninger":"Nem", "aflukningerne":"Nem",  "opslagskant":"Nem", "opslagskanten":"Nem", "opslagskanter":"Nem", "opslagskanterne":"Nem", "lænke":"Nem", "lænken":"Nem", "lænker":"Nem", "lænkerne":"Nem", "omgangsstart":"Nem", "forstykke":"Nem", "bagstykke":"Nem", "ryg":"Nem", "r":"Forkortelser", "vr":"Forkortelser", "omg":"Forkortelser", "indt":"Forkortelser", "udt":"Forkortelser", "m":"Forkortelser", "p":"Forkortelser", "gent":"Forkortelser", "sm":"Forkortelser", "mm":"Forkortelser", "arb":"Forkortelser", "km":"Forkortelser", "vrs":"Forkortelser", "vrangs":"Forkortelser", "rts":"Forkortelser", "rundp":"Forkortelser", "fv":"Forkortelser", "kantm":"Forkortelser", "enkeltindt":"Forkortelser", "raglanindt":"Forkortelser", "glatst":"Forkortelser", "knaphul":"Middel", "knaphullet":"Middel", "knaphuller":"Middel", "knaphullerne":"Middel", "drejet":"Middel", "drejet ret":"Middel", "drejet vrang":"Middel", "strømpepind":"Middel", "strømpepinden":"Middel", "strømpepinde":"Middel","strømpepindene":"Middel", "omslag":"Middel", "omslaget":"Middel", "omslagene":"Middel", "indtagning":"Middel", "indtagningen":"Middel", "indtagninger":"Middel", "indtagninggerne":"Middel", "rib":"Middel", "ribben":"Middel", "ribbort":"Middel", "ribpind":"Middel", "ribkant":"Middel", "ribkanten":"Middel", "ribkanter":"Middel", "ribkanterne":"Middel", "rillekant":"Middel", "rillekanten":"Middel", "rillekanter":"Middel", "rillekanterne":"Middel", "magic loop":"Middel", "magic loops":"Middel", "raglan":"Middel", "raglanen":"Middel", "raglansøm":"Middel", "raglansømmene":"Middel", "søm":"Middel", "sømme":"Middel", "sømmene":"Middel", "sømrum":"Middel", "mærketråd":"Middel", "mærketråden":"Middel", "mærketråde":"Middel", "mærketrådene":"Middel", "italiensk aflukning":"Middel", "italienske aflukninger":"Middel", "retsidepind":"Middel", "retsidepinden":"Middel", "retsidepindene":"Middel", "retsidepindene":"Middel", "maskeholder":"Middel", "maskeholderen":"Middel", "maskeholder":"Middel", "maskeholderne":"Middel", "løkkeopslag":"Middel", "løkkeopslaget":"Middel", "løkkeopslagene":"Middel", "blok":"Middel", "blokken":"Middel", "blokke":"Middel", "blokkene":"Middel", "mønster":"Svær", "mønsteret":"Svær", "mønstre":"Svær", "mønstrene":"Svær", "ærmekuppel":"Svær", "ærmekuppelen":"Svær", "ærmekupler":"Svær", "ærmekuplerne":"Svær", "vendepind":"Svær", "vendepinden":"Svær", "vendepinde":"Svær", "vendepindene":"Svær", "diagram":"Svær", "boble":"Svær", "boblen":"Svær", "bobler":"Svær", "boblerne":"Svær", "dobbelt omslag":"Svær", "hulmønster":"Svær", "hulmønstre":"Svær", "montering":"Svær", "skulderaflukning":"Svær", "skulderaflukningen":"Svær", "skulderaflukninger":"Svær", "skuldersøm":"Svær", "skuldersømmen":"Svær", "skuldersømmene":"Svær", "retsidepind":"Svær", "retsidepinden":"Svær", "retsidepinde":"Svær", "retsidepindene":"Svær", "elastik":"Svær", "elastikken":"Svær", "elastikker":"Svær", "elastikkerne":"Svær", "elastiksnor":"Svær", "elastiksnoren":"Svær", "elastiksnorer":"Svær", "elastiksnorene":"Svær", "german short row":"Svær", "german short rows":"Svær", "sildebensmønster":"Svær", "sildebensmønsteret":"Svær", "overtræksindtagning":"Svær", "overtræksindtagningen":"Svær", "mønsterbort":"Svær", "sidesømsmarkør":"Svær", "sidesømsmarkøren":"Svær", "sidesømsmarkører":"Svær", "sidesømsmarkørene":"Svær", "ærmesøm":"Svær", "ærmesømmen":"Svær", "ærmesømme":"Svær", "ærmesømmene":"Svær", "raglanindtagning":"Svær", "raglanindtagningen":"Svær", "raglanindtagninger":"Svær", "raglanindtagningerne":"Svær"}
score = []
for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w==k:
            score.append(v)

        
Counter(score)
# Out:
# Counter({'Forkortelser': 1341, 'Middel': 324, 'Nem': 1222, 'Svær': 61})

# %%
# Opskrift 1

# %%
text25= 'Middel/Basket_weave.txt'

with open(text25, encoding="utf8") as f:
    text25= f.read()

f.close()

# %%
AntalTegn25=len(text25)

# %%
text25_lower = text25.lower()
text25_punkt = text25_lower.replace("."," ")

# %%
antalTegn25=len(text25_punkt)

# %%
tokens25=nltk.word_tokenize(text25_punkt)

# %%
# Opskrift 2

# %%
text26= 'Middel/Blue_shore.txt'

with open(text26, encoding="utf8") as f:
    text026= f.read()

f.close()

# %%
text26_lower = text026.lower()
text26_punkt = text26_lower.replace("."," ")

# %%
AntalTegn26=len(text26_punkt)

# %%
tokens26=nltk.word_tokenize(text26_punkt)

# %%
# Opskrift 3

# %%
text27= 'Middel/DROPS_226_21.txt'

with open(text27, encoding="utf8") as f:
    text027= f.read()

f.close()

# %%
text27_lower = text027.lower()
text27_punkt = text27_lower.replace("."," ")

# %%
AntalTegn27=len(text27_punkt)

# %%
tokens27=nltk.word_tokenize(text27_punkt)

# %%
# Opskrift 4

# %%
text28= 'Middel/DROPS_227_25.txt'

with open(text28, encoding="utf8") as f:
    text028= f.read()

f.close()

# %%
text28_lower = text028.lower()
text28_punkt = text28_lower.replace("."," ")

# %%
AntalTegn28=len(text28_punkt)

# %%
tokens28=nltk.word_tokenize(text28_punkt)

# %%
# Opskrift 5

text29= 'Middel/Freya_sweater.txt'

with open(text29, encoding="utf8") as f:
    text029= f.read()

f.close()

# %%
text29_lower = text029.lower()
text29_punkt = text29_lower.replace("."," ")

# %%
AntalTegn29=len(text29_punkt)

# %%
tokens29=nltk.word_tokenize(text29_punkt)

# %%
# Opskrift 6

# %%
text30= 'Middel/Gul_damebluse.txt'

with open(text30, encoding="utf8") as f:
    text030= f.read()

f.close()

# %%
text30_lower = text030.lower()
text30_punkt = text30_lower.replace("."," ")

# %%
AntalTegn30=len(text30_punkt)

# %%
tokens30=nltk.word_tokenize(text30_punkt)

# %%
# Opskrift 7

# %%
text31= 'Middel/Gunhild_cardigan.txt'

with open(text31, encoding="utf8") as f:
    text031= f.read()

f.close()

# %%
text31_lower = text031.lower()
text31_punkt = text31_lower.replace("."," ")

# %%
AntalTegn31=len(text31_punkt)

# %%
tokens31=nltk.word_tokenize(text31_punkt)

# %%
# Opskrift 8

# %%
text32= 'Middel/Helgi_sweater.txt'

with open(text32, encoding='utf8') as f:
    text32= f.read()

f.close()

# %%
text32_lower = text32.lower()
text32_punkt = text32_lower.replace("."," ")

# %%
AntalTegn32=len(text32_punkt)

# %%
tokens32=nltk.word_tokenize(text32_punkt)

# %%
# Opskrift 9

# %%
text33= 'Middel/Herresweater_med_snoninger.txt'

with open(text33, encoding="utf8") as f:
    text33= f.read()

f.close()

# %%
text33_lower = text33.lower()
text33_punkt = text33_lower.replace("."," ")

# %%
AntalTegn33=len(text33_punkt)

# %%
tokens33=nltk.word_tokenize(text33_punkt)

# %%
# Opskrift 10

# %%
text34= 'Middel/Lina_sweater.txt'

with open(text34, encoding="utf8") as f:
    text34= f.read()

f.close()

# %%
text34_lower = text34.lower()
text34_punkt = text34_lower.replace("."," ")

# %%
AntalTegn34=len(text34_punkt)

# %%
AntalTegn34
# Out:
# 3698

# %%
tokens34=nltk.word_tokenize(text34_punkt)

# %%
# Opskrift 11

# %%
text35= 'Middel/Lola_sweater.txt'

with open(text35, encoding="utf8") as f:
    text35= f.read()

f.close()

# %%
text35_lower = text35.lower()
text35_punkt = text35_lower.replace("."," ")

# %%
AntalTegn35=len(text35_punkt)

# %%
tokens35=nltk.word_tokenize(text35_punkt)

# %%
# Opskrift 12

# %%
text36= 'Middel/Lykkejumper.txt'

with open(text36, encoding="utf8") as f:
    text036= f.read()

f.close()

# %%
text36_lower = text036.lower()
text36_punkt = text36_lower.replace("."," ")

# %%
AntalTegn36=len(text36_punkt)

# %%
tokens36=nltk.word_tokenize(text36_punkt)

# %%
# Opskrift 13

# %%
text37= 'Middel/Lærke_sweater.txt'

with open(text37, encoding="utf8") as f:
    text037= f.read()

f.close()

# %%
text37_lower = text037.lower()
text37_punkt = text37_lower.replace("."," ")

# %%
AntalTegn37=len(text37_punkt)

# %%
tokens37=nltk.word_tokenize(text37_punkt)

# %%
# Opskrift 14

# %%
text38= 'Middel/Mayan_sun.txt'

with open(text38, encoding="utf8") as f:
    text038= f.read()

f.close()

# %%
text38_lower = text038.lower()
text38_punkt = text38_lower.replace("."," ")

# %%
AntalTegn38=len(text38_punkt)

# %%
tokens38=nltk.word_tokenize(text38_punkt)

# %%
# Opskrift 15

# %%
text39= 'Middel/Mette_sweater.txt'

with open(text39, encoding="utf8") as f:
    text039= f.read()

f.close()

# %%
text39_lower = text039.lower()
text39_punkt = text39_lower.replace("."," ")

# %%
antalTegn39=len(text39_punkt)

# %%
tokens39=nltk.word_tokenize(text39_punkt)

# %%
# Opskrift 16

# %%
text40= 'Middel/Pepposhirt.txt'

with open(text40, encoding="utf8") as f:
    text040= f.read()

f.close()

# %%
text40_lower = text040.lower()
text40_punkt = text40_lower.replace("."," ")

# %%
AntalTegn40=len(text40_punkt)

# %%
tokens40=nltk.word_tokenize(text40_punkt)

# %%
# Opskrift 17

# %%
text41= 'Middel/Prairie_rose_sweater.txt'

with open(text41, encoding="utf8") as f:
    text041= f.read()

f.close()

# %%
text41_lower = text041.lower()
text41_punkt = text41_lower.replace("."," ")

# %%
AntalTegn41=len(text41_punkt)

# %%
tokens41=nltk.word_tokenize(text41_punkt)

# %%
# Opskrift 18

# %%
text42= 'Middel/Pritchard.txt'

with open(text42, encoding="utf8") as f:
    text042= f.read()

f.close()

# %%
text42_lower = text042.lower()
text42_punkt = text42_lower.replace("."," ")

# %%
AntalTegn42=len(text42_punkt)

# %%
tokens42=nltk.word_tokenize(text42_punkt)

# %%
# Opskrift 19

# %%
text43= 'Middel/Sheepy_sweater.txt'

with open(text43, encoding="utf8") as f:
    text043= f.read()

f.close()

# %%
text43_lower = text043.lower()
text43_punkt = text43_lower.replace("."," ")

# %%
AntalTegn43=len(text43_punkt)

# %%
tokens43=nltk.word_tokenize(text43_punkt)

# %%
# Opskrift 20

# %%
text44= 'Middel/Sophia_sweater.txt'

with open(text44, encoding="utf8") as f:
    text044= f.read()

f.close()

# %%
text44_lower = text044.lower()
text44_punkt = text44_lower.replace("."," ")

# %%
AntalTegn44=len(text44_punkt)

# %%
tokens44=nltk.word_tokenize(text44_punkt)

# %%
# Opskrift 21

# %%
text45= 'Middel/Sophia_sweater_chunky.txt'

with open(text45, encoding="utf8") as f:
    text045= f.read()

f.close()

# %%
text45_lower = text045.lower()
text45_punkt = text45_lower.replace("."," ")

# %%
AntalTegn45=len(text45_punkt)

# %%
tokens45=nltk.word_tokenize(text45_punkt)

# %%
# Opskrift 22

# %%
text46= 'Middel/Sweater_no8.txt'

with open(text46, encoding="utf8") as f:
    text046= f.read()

f.close()

# %%
text46_lower = text046.lower()
text46_punkt = text46_lower.replace("."," ")

# %%
AntalTegn46=len(text46_punkt)

# %%
tokens46=nltk.word_tokenize(text46_punkt)

# %%
# Opskrift 23

# %%
text47= 'Middel/Trescao_jumper.txt'

with open(text47, encoding="utf8") as f:
    text047= f.read()

f.close()

# %%
text47_lower = text047.lower()
text47_punkt = text47_lower.replace("."," ")

# %%
AntalTegn47=len(text47_punkt)

# %%
tokens47=nltk.word_tokenize(text47_punkt)

# %%
# Opskrift 24

# %%
text48= 'Middel/Uda_sweater.txt'

with open(text48, encoding="utf8") as f:
    text048= f.read()

f.close()

# %%
text48_lower = text048.lower()
text48_punkt = text48_lower.replace("."," ")

# %%
AntalTegn48=len(text48_punkt)

# %%
tokens48=nltk.word_tokenize(text48_punkt)

# %%
# Opskrift 25

# %%
text49= 'Middel/Vigga_sweater.txt'

with open(text49, encoding="utf8") as f:
    text049= f.read()

f.close()

# %%
text49_lower = text049.lower()
text49_punkt = text49_lower.replace("."," ")

# %%
AntalTegn49=len(text49_punkt)

# %%
tokens49=nltk.word_tokenize(text49_punkt)

# %%
# Score for alle svære opskrifter

# %%
samlede_svære0 = []

path = os.path.join("Svære")

for fil in os.scandir(path):
    with open (fil, encoding="utf8") as f:
        samlede_svære0.append(f.read())

# %%
samlede_svære1= "".join(samlede_svære0)

# %%
type(samlede_svære1)
# Out:
# str

# %%
samlede_svære1
# Out:
# '\ufeffAlvi - en klassisk nordisk sweater\n\nSærlige forkortelser\nUdt (udtagning): Løft lænken mellem 2 m op på pin-\nden og strik den drejet ret.\nO-indt (overtræksindtagning): Tag 1 r løst af, 1 r,\ntræk den løse m over den netop strikkede.\nArbejdsgang\nFor- og bagstykke strikkes rundt i ét stykke op til\nærmegabene. Derefter strikkes ærmerne, som sæt-\ntes ind i ærmegabene, og raglanbærestykket strik-\nkes samlet. Eneste montering er en lille søm under\nærmene.\nKrop\nSlå 192 (216) 240 (264) 288 m op på den lange\nrundp 3½ mm med fv A og strik rundt, begynd med 4\nomg rib (1r, 1 vr).\nSæt nu markør ved omg’s begyndelse (= venstre\nside) og efter 96 (108) 120 (132) 144 m (= højre\nside).\nStrik mønster efter diagram A. Strik først den neder-\nste mønsterbort over 12 omg og fortsæt herefter med\nde 4 omg ”sildebensmønster”, som gentages.\nStrik lige op til arb måler 42 (42) 41 (41) 40 cm.\nLuk nu 11 m til ærmegab i begge sider således:\nLuk 6 m i starten af omg, strik forstykkets 
# ...

# %%
text_lower = samlede_svære1.lower()

# %%
samlede_svære2 = text_lower.replace("."," ")

# %%
AntalTegnSvære = len(samlede_svære2)

# %%
AntalTegnSvære
# Out:
# 151384

# %%
AntalTegnSvære=len(samlede_svære2)

# %%
tokens_svære2=nltk.word_tokenize(samlede_svære2)

# %%
txt=tokens_svære2
ubestemtestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasker":1, "løkkeopslag":1, "rundpind":1, "rundpinde":1, "bærestykke":1, "maske":1, "masker":1, "ærmegab":1, "maskemarkør":1, "maskemarkører":1, "markør":1, "markører":1, "aflukning":1, "aflukninger":1,  "opslagskant":1, "opslagskanter":1, "lænke":1, "lænker":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "knaphul":1, "knaphuller":1, "drejet":1, "drejet ret":1, "drejet vrang":1, "strømpepind":1,  "strømpepinde":1, "omslag":1, "indtagning":1, "indtagninger":1, "rib":1, "ribbort":1, "ribpind":1, "ribkant":1, "ribkanter":1, "rillekant":1, "rillekanter":1, "magic loop":1, "magic loops":1, "raglan":1, "raglansøm":1, "søm":1, "sømme":1, "sømrum":1, "mærketråd":1, "mærketråde":1, "italiensk aflukning":1, "italienske aflukninger":1, "retsidepind":1, "retsidepinde":1, "maskeholder":1, "maskeholder":1, "løkkeopslag":1, "løkkeopslaget":1, "blok":1, "blokke":1, "mønster":1, "mønstre":1, "ærmekuppel":1, "ærmekupler":1, "vendepind":1, "vendepinde":1, "diagram":1, "boble":1, "bobler":1, "dobbelt omslag":1, "hulmønster":1, "hulmønstre":1, "montering":1, "skulderaflukning":1, "skulderaflukninger":1, "skuldersøm":1, "retsidepind":1, "retsidepinde":1, "elastik":1, "elastikker":1, "elastiksnor":1, "elastiksnorer":1, "german short row":1, "german short rows":1, "sildebensmønster":1, "overtræksindtagning":1, "mønsterbort":1, "sidesømsmarkør":1, "sidesømsmarkører":1, "ærmesøm":1, "ærmesømme":1, "raglanindtagning":1, "raglanindtagninger":1}
score_ubestemte = 0

for w in txt:
    for k, v in ubestemtestrikkeord_dictionary.items():
        if w == k:
            score_ubestemte = score_ubestemte + v
            print("Item score:", k, v)
                                
print("Samlet score: ", score_ubestemte)
# Out:
# Item score: drejet 1
# Item score: ret 1
# Item score: overtræksindtagning 1
# Item score: bagstykke 1
# Item score: montering 1
# Item score: søm 1
# Item score: rib 1
# Item score: markør 1
# Item score: mønster 1
# Item score: diagram 1
# Item score: mønsterbort 1
# Item score: sildebensmønster 1
# Item score: ærmegab 1
# Item score: sidesømsmarkør 1
# Item score: rib 1
# Item score: glatstrik 1
# Item score: mønster 1
# Item score: diagram 1
# Item score: diagram 1
# Item score: diagram 1
# Item score: ærmesøm 1
# Item score: diagram 1
# Item score: diagram 1
# Item score: diagram 1
# Item score: ærmesøm 1
# Item score: diagram 1
# Item score: rundpind 1
# Item score: diagram 1
# Item score: sildebensmønster 1
# Item score: diagram 1
# Item score: ærmesøm 1
# Item score: mønsterbort 1
# Item score: maske 1
# Item score: sildebensmønster 1
# Item score: markører 1
# Item score: mønster 1
# Item score: raglan 1
# Item score: mønster 1
# Item score: raglan 1
# Item score: mønster 1
# ...

# %%
txt = tokens_svære2
bestemtestrikkeord_dictionary={"kantmasken":1,"kantmaskerne":1, "rundpinden":1, "rundpindene":1, "bærestykket":1, "masken":1, "maskerne":1, "ærmegabet":1, "maskemarkøren":1, "maskemarkørerne":1, "markøren":1, "markørerne":1, "aflukningen":1, "aflukningerne":1, "opslagskanten":1, "opslagskanterne":1, "lænken":1, "lænkerne":1, "knaphullet":1, "knaphullerne":1, "strømpepinden":1, "strømpepinde":1,"strømpepindene":1, "omslaget":1, "omslagene":1, "indtagningen":1, "indtagninggerne":1, "ribben":1, "ribkanten":1, "ribkanterne":1, "rillekanten":1, "rillekanterne":1, "raglanen":1, "raglansømmene":1, "sømmene":1, "mærketråden":1, "mærketrådene":1, "retsidepinden":1, "retsidepindene":1, "maskeholderen":1, "maskeholderne":1, "løkkeopslaget":1, "løkkeopslagene":1, "blokken":1, "blokkene":1, "mønsteret":1,  "mønstrene":1, "ærmekuppelen":1, "ærmekuplerne":1, "vendepinden":1, "vendepindene":1, "boblen":1, "boblerne":1,   "skulderaflukningen":1, "skuldersømmen":1, "skuldersømmene":1, "retsidepinden":1, "retsidepindene":1, "elastikken":1, "elastikkerne":1, "elastiksnoren":1, "elastiksnorer":1, "elastiksnorene":1, "sildebensmønsteret":1, "overtræksindtagningen":1, "sidesømsmarkøren":1, "sidesømsmarkørene":1, "ærmesømmen":1, "ærmesømmene":1, "raglanindtagningen":1, "raglanindtagningerne":1}
score_svære = 0

for w in txt:
    for k, v in bestemtestrikkeord_dictionary.items():
        if w == k:
            score_svære = score_svære + v
            print("Item score:", k, v)
            
print("Samlet score: ", score_svære)
# Out:
# Item score: lænken 1
# Item score: aflukningerne 1
# Item score: ærmesømmen 1
# Item score: maskerne 1
# Item score: mønsteret 1
# Item score: sildebensmønsteret 1
# Item score: mønsteret 1
# Item score: ærmegabet 1
# Item score: ærmegabet 1
# Item score: strømpepinde 1
# Item score: mønsteret 1
# Item score: retsidepindene 1
# Item score: skuldersømmene 1
# Item score: ribben 1
# Item score: elastikkerne 1
# Item score: ærmegabet 1
# Item score: ærmegabet 1
# Item score: ærmegabet 1
# Item score: maskerne 1
# Item score: lænken 1
# Item score: mønsteret 1
# Item score: opslagskanten 1
# Item score: opslagskanten 1
# Item score: mærketråden 1
# Item score: mærketråden 1
# Item score: omslagene 1
# Item score: omslaget 1
# Item score: strømpepinde 1
# Item score: bærestykket 1
# Item score: maskerne 1
# Item score: kantmaskerne 1
# Item score: strømpepinde 1
# Item score: strømpepinde 1
# Item score: mærketråden 1
# Item score: bærestykket 1
# Item score: bærestykket 1
# ...

# %%
txt=tokens_svære
allestrikkeord_dictionary={"ret":"Nem", "vrang":"Nem", "retmaske":"Nem", "vrangmaske":"Nem", "retstrik":"Nem", "glatstrik":"Nem", "kantmaske":"Nem", "kantmasken":"Nem", "kantmasker":"Nem", "kantmaskerne":"Nem", "løkkeopslag":"Nem", "rundpind":"Nem", "rundpinden":"Nem", "rundpinde":"Nem", "rundpindene":"Nem", "bærestykke":"Nem", "bærestykket":"Nem", "maske":"Nem", "masken":"Nem", "masker":"Nem", "maskerne":"Nem", "ærmegab":"Nem", "ærmegabet":"Nem", "maskemarkør":"Nem", "maskemarkøren":"Nem", "maskemarkører":"Nem", "maskemarkørerne":"Nem", "markør":"Nem", "markøren":"Nem", "markører":"Nem", "markørerne":"Nem", "aflukning":"Nem", "aflukningen":"Nem", "aflukninger":"Nem", "aflukningerne":"Nem",  "opslagskant":"Nem", "opslagskanten":"Nem", "opslagskanter":"Nem", "opslagskanterne":"Nem", "lænke":"Nem", "lænken":"Nem", "lænker":"Nem", "lænkerne":"Nem", "omgangsstart":"Nem", "forstykke":"Nem", "bagstykke":"Nem", "ryg":"Nem", "r":"Forkortelser", "vr":"Forkortelser", "omg":"Forkortelser", "indt":"Forkortelser", "udt":"Forkortelser", "m":"Forkortelser", "p":"Forkortelser", "gent":"Forkortelser", "sm":"Forkortelser", "mm":"Forkortelser", "arb":"Forkortelser", "km":"Forkortelser", "vrs":"Forkortelser", "vrangs":"Forkortelser", "rts":"Forkortelser", "rundp":"Forkortelser", "fv":"Forkortelser", "kantm":"Forkortelser", "enkeltindt":"Forkortelser", "raglanindt":"Forkortelser", "glatst":"Forkortelser", "knaphul":"Middel", "knaphullet":"Middel", "knaphuller":"Middel", "knaphullerne":"Middel", "drejet":"Middel", "drejet ret":"Middel", "drejet vrang":"Middel", "strømpepind":"Middel", "strømpepinden":"Middel", "strømpepinde":"Middel","strømpepindene":"Middel", "omslag":"Middel", "omslaget":"Middel", "omslagene":"Middel", "indtagning":"Middel", "indtagningen":"Middel", "indtagninger":"Middel", "indtagninggerne":"Middel", "rib":"Middel", "ribben":"Middel", "ribbort":"Middel", "ribpind":"Middel", "ribkant":"Middel", "ribkanten":"Middel", "ribkanter":"Middel", "ribkanterne":"Middel", "rillekant":"Middel", "rillekanten":"Middel", "rillekanter":"Middel", "rillekanterne":"Middel", "magic loop":"Middel", "magic loops":"Middel", "raglan":"Middel", "raglanen":"Middel", "raglansøm":"Middel", "raglansømmene":"Middel", "søm":"Middel", "sømme":"Middel", "sømmene":"Middel", "sømrum":"Middel", "mærketråd":"Middel", "mærketråden":"Middel", "mærketråde":"Middel", "mærketrådene":"Middel", "italiensk aflukning":"Middel", "italienske aflukninger":"Middel", "retsidepind":"Middel", "retsidepinden":"Middel", "retsidepindene":"Middel", "retsidepindene":"Middel", "maskeholder":"Middel", "maskeholderen":"Middel", "maskeholder":"Middel", "maskeholderne":"Middel", "løkkeopslag":"Middel", "løkkeopslaget":"Middel", "løkkeopslagene":"Middel", "blok":"Middel", "blokken":"Middel", "blokke":"Middel", "blokkene":"Middel", "mønster":"Svær", "mønsteret":"Svær", "mønstre":"Svær", "mønstrene":"Svær", "ærmekuppel":"Svær", "ærmekuppelen":"Svær", "ærmekupler":"Svær", "ærmekuplerne":"Svær", "vendepind":"Svær", "vendepinden":"Svær", "vendepinde":"Svær", "vendepindene":"Svær", "diagram":"Svær", "boble":"Svær", "boblen":"Svær", "bobler":"Svær", "boblerne":"Svær", "dobbelt omslag":"Svær", "hulmønster":"Svær", "hulmønstre":"Svær", "montering":"Svær", "skulderaflukning":"Svær", "skulderaflukningen":"Svær", "skulderaflukninger":"Svær", "skuldersøm":"Svær", "skuldersømmen":"Svær", "skuldersømmene":"Svær", "retsidepind":"Svær", "retsidepinden":"Svær", "retsidepinde":"Svær", "retsidepindene":"Svær", "elastik":"Svær", "elastikken":"Svær", "elastikker":"Svær", "elastikkerne":"Svær", "elastiksnor":"Svær", "elastiksnoren":"Svær", "elastiksnorer":"Svær", "elastiksnorene":"Svær", "german short row":"Svær", "german short rows":"Svær", "sildebensmønster":"Svær", "sildebensmønsteret":"Svær", "overtræksindtagning":"Svær", "overtræksindtagningen":"Svær", "mønsterbort":"Svær", "sidesømsmarkør":"Svær", "sidesømsmarkøren":"Svær", "sidesømsmarkører":"Svær", "sidesømsmarkørene":"Svær", "ærmesøm":"Svær", "ærmesømmen":"Svær", "ærmesømme":"Svær", "ærmesømmene":"Svær", "raglanindtagning":"Svær", "raglanindtagningen":"Svær", "raglanindtagninger":"Svær", "raglanindtagningerne":"Svær"}
skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score_svære = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score_svære = score_svære + v
            print("Item score:", k, v)
            
print("Samlet score: ", score_svære)
# Out:
# Item score: udt 1
# Item score: lænken 1
# Item score: m 1
# Item score: drejet 2
# Item score: ret 1
# Item score: overtræksindtagning 3
# Item score: r 1
# Item score: r 1
# Item score: m 1
# Item score: bagstykke 1
# Item score: montering 3
# Item score: søm 2
# Item score: m 1
# Item score: rundp 1
# Item score: mm 1
# Item score: fv 1
# Item score: omg 1
# Item score: rib 2
# Item score: vr 1
# Item score: markør 1
# Item score: omg 1
# Item score: m 1
# Item score: mønster 3
# Item score: diagram 3
# Item score: mønsterbort 3
# Item score: omg 1
# Item score: omg 1
# Item score: sildebensmønster 3
# Item score: arb 1
# Item score: m 1
# Item score: ærmegab 1
# Item score: m 1
# Item score: omg 1
# Item score: m 1
# Item score: m 1
# Item score: sidesømsmarkør 3
# Item score: m 1
# Item score: m 1
# Item score: m 1
# Item score: aflukningerne 1
# Item score: fv 1
# Item score: m 1
# Item score: p 1
# Item score: arb 1
# Item score: m 1
# Item score: fv 1
# Item score: omg 1
# ...

# %%
RettetScoreSvære=score_svære/AntalTegnSvære*100
RettetScoreSvære
# Out:
# 3.870290123130582

# %%
def find_alle_pron (samlede_svære0):
    pronominer = []
    for tekst in samlede_svære0: 
        doc = nlp(tekst)
        for w in doc:
            if w.pos_ == "PRON": 
                pronominer.append(w.lemma_)
    elements_to_count = (item for item in pronominer)
    c = Counter(elements_to_count)
    return c.most_common(20)

# %%
find_alle_pron(samlede_svære0)
# Out:
# [('hver', 258),
#  ('det', 66),
#  ('du', 55),
#  ('den', 52),
#  ('sig', 36),
#  ('de', 28),
#  ('denne', 14),
#  ('Det', 10),
#  ('man', 9),
#  ('der', 8),
#  ('som', 7),
#  ('Den', 6),
#  ('HERFRA', 3),
#  ('anden', 3),
#  ('ens', 3),
#  ('hvilken', 2),
#  ('Dette', 2),
#  ('en', 2),
#  ('Der', 2),
#  ('Jeg', 2)]

# %%
# Opskrift 1

# %%
text50= 'Svære/Alvi_sweater.txt'

with open(text50, encoding='utf8') as f:
    text050= f.read()

f.close()

# %%
text50_lower = text050.lower()
text50_punkt = text50_lower.replace("."," ")

# %%
AntalTegn50=len(text50_punkt)

# %%
tokens50=nltk.word_tokenize(text50_punkt)

# %%
# Opskrift 2

# %%
text51= 'Svære/Anne-Cathrinetrøje.txt'

with open(text51, encoding="utf8") as f:
    text051= f.read()

f.close()

# %%
text51_lower = text051.lower()
text51_punkt = text51_lower.replace("."," ")

# %%
AntalTegn51=len(text51_punkt)

# %%
tokens51=nltk.word_tokenize(text51_punkt)

# %%
# Opskrift 3

# %%
text52= 'Svære/Astridtrøje.txt'

with open(text52, encoding="utf8") as f:
    text052= f.read()

f.close()

# %%
text52_lower = text052.lower()
text52_punkt = text52_lower.replace("."," ")

# %%
AntalTegn52=len(text52_punkt)

# %%
tokens52=nltk.word_tokenize(text52_punkt)

# %%
# Opskrift 4

# %%
text53= 'Svære/Athena_sweater.txt'

with open(text53, encoding="utf8") as f:
    text053= f.read()

f.close()

# %%
text53_lower = text053.lower()
text53_punkt = text53_lower.replace("."," ")

# %%
AntalTegn53=len(text53_punkt)

# %%
tokens53=nltk.word_tokenize(text53_punkt)

# %%
# Opskrift 5

# %%
text54= 'Svære/Big_sur_cardigan.txt'

with open(text54, encoding="utf8") as f:
    text054= f.read()

f.close()

# %%
text54_lower = text054.lower()
text54_punkt = text54_lower.replace("."," ")

# %%
tokens54=nltk.word_tokenize(text54_punkt)

# %%
# Opskrift 6

# %%
text55= 'Svære/Cardigan_med_hulmønster.txt'

with open(text55, encoding="utf8") as f:
    text055= f.read()

f.close()

# %%
text55_lower = text055.lower()
text55_punkt = text55_lower.replace("."," ")

# %%
tokens55=nltk.word_tokenize(text55_punkt)

# %%
# Opskrift 7

# %%
text56= 'Svære/Chill_chaser.txt'

with open(text56, encoding="utf8") as f:
    text056= f.read()

f.close()

# %%
text56_lower = text056.lower()
text56_punkt = text56_lower.replace("."," ")

# %%
tokens56=nltk.word_tokenize(text56_punkt)

# %%
# Opskrift 8

# %%
text57= 'Svære/Cloud_catcher.txt'

with open(text57, encoding="utf8") as f:
    text057= f.read()

f.close()

# %%
text57_lower = text056.lower()
text57_punkt = text57_lower.replace("."," ")

# %%
tokens57=nltk.word_tokenize(text57_punkt)

# %%
# Opskrift 9

# %%
text58= 'Svære/Colorful_walk.txt'

with open(text58, encoding="utf8") as f:
    text058= f.read()

f.close()

# %%
text58_lower = text058.lower()
text58_punkt = text58_lower.replace("."," ")

# %%
tokens58=nltk.word_tokenize(text58_punkt)

# %%
# Opskrift 10

# %%
text59= 'Svære/Damesweater_med_hulmønster.txt'

with open(text59, encoding="utf8") as f:
    text059= f.read()

f.close()

# %%
text59_lower = text059.lower()
text59_punkt = text59_lower.replace("."," ")

# %%
tokens59=nltk.word_tokenize(text59_punkt)

# %%
# Opskrift 11

# %%
text60= 'Svære/Damesweater_med_striber_og_hulmønster.txt'

with open(text60, encoding="utf8") as f:
    text060= f.read()

f.close()

# %%
text60_lower = text060.lower()
text60_punkt = text60_lower.replace("."," ")

# %%
tokens60=nltk.word_tokenize(text60_punkt)

# %%
# Opskrift 12

# %%
text61= 'Svære/Leaf_ring_cardigan.txt'

with open(text61, encoding="utf8") as f:
    text061= f.read()

f.close()

# %%
text61_lower = text061.lower()
text61_punkt = text61_lower.replace("."," ")

# %%
tokens61=nltk.word_tokenize(text61_punkt)

# %%
# Opskrift 13

# %%
text62= 'Svære/Lucky_charm_sweater.txt'

with open(text62, encoding="utf8") as f:
    text062= f.read()

f.close()

# %%
text62_lower = text062.lower()
text62_punkt = text62_lower.replace("."," ")

# %%
tokens62=nltk.word_tokenize(text62_punkt)

# %%
# Opskrift 14

# %%
text63= 'Svære/Miss_moss_sweater.txt'

with open(text63, encoding="utf8") as f:
    text063= f.read()

f.close()

# %%
text63_lower = text063.lower()
text63_punkt = text63_lower.replace("."," ")

# %%
tokens63=nltk.word_tokenize(text63_punkt)

# %%
# Opskrift 15

# %%
text64= 'Svære/Mønstret_sweater.txt'

with open(text64, encoding="utf8") as f:
    text064= f.read()

f.close()

# %%
text64_lower = text064.lower()
text64_punkt = text64_lower.replace("."," ")

# %%
tokens64=nltk.word_tokenize(text64_punkt)

# %%
# Opskrift 16

# %%
text65= 'Svære/Pandora_sweater.txt'

with open(text65, encoding="utf8") as f:
    text065= f.read()

f.close()

# %%
text65_lower = text065.lower()
text65_punkt = text65_lower.replace("."," ")

# %%
tokens65=nltk.word_tokenize(text65_punkt)

# %%
# Opskrift 17

# %%
text66= 'Svære/Pearlescent_top.txt'

with open(text66, encoding="utf8") as f:
    text066= f.read()

f.close()

# %%
text66_lower = text066.lower()
text66_punkt = text66_lower.replace("."," ")

# %%
tokens66=nltk.word_tokenize(text66_punkt)

# %%
# Opskrift 18

# %%
text67= 'Svære/Provence_dream.txt'

with open(text67, encoding="utf8") as f:
    text067= f.read()

f.close()

# %%
text67_lower = text067.lower()
text67_punkt = text67_lower.replace("."," ")

# %%
tokens67=nltk.word_tokenize(text67_punkt)

# %%
# Opskrift 19

# %%
text68= 'Svære/Rebild_cardigan.txt'

with open(text68, encoding="utf8") as f:
    text068= f.read()

f.close()

# %%
text68_lower = text068.lower()
text68_punkt = text68_lower.replace("."," ")

# %%
tokens68=nltk.word_tokenize(text68_punkt)

# %%
# Opskrift 20

# %%
text69= 'Svære/Smuk_snoningssweater.txt'

with open(text69, encoding="utf8") as f:
    text069= f.read()

f.close()

# %%
text69_lower = text069.lower()
text69_punkt = text69_lower.replace("."," ")

# %%
tokens69=nltk.word_tokenize(text69_punkt)

# %%
# Opskrift 21

# %%
text70= 'Svære/Soft_journey_sweater.txt'

with open(text70, encoding="utf8") as f:
    text070= f.read()

f.close()

# %%
text70_lower = text070.lower()
text70_punkt = text70_lower.replace("."," ")

# %%
tokens70=nltk.word_tokenize(text70_punkt)

# %%
# Opskrift 22

# %%
text71= 'Svære/Spring_parade_sweater.txt'

with open(text71, encoding="utf8") as f:
    text071= f.read()

f.close()

# %%
text71_lower = text071.lower()
text71_punkt = text71_lower.replace("."," ")

# %%
tokens71=nltk.word_tokenize(text71_punkt)

# %%
# Opskrift 23

# %%
text72= 'Svære/Sweater_med_spidser_og_striber.txt'

with open(text72, encoding="utf8") as f:
    text072= f.read()

f.close()

# %%
text72_lower = text072.lower()
text72_punkt = text72_lower.replace("."," ")

# %%
tokens72=nltk.word_tokenize(text72_punkt)

# %%
# Opskrift 24

# %%
text73= 'Svære/Sweet_as_candy_sweater.txt'

with open(text73, encoding='utf8') as f:
    text073= f.read()

f.close()

# %%
text73_lower = text073.lower()
text73_punkt = text73_lower.replace("."," ")

# %%
tokens73=nltk.word_tokenize(text73_punkt)

# %%
# Opskrift 25

# %%
text74= 'Svære/Tree_of_life_sweater.txt'

with open(text74, encoding="utf8") as f:
    text074= f.read()

f.close()

# %%
text74_lower = text074.lower()
text74_punkt = text74_lower.replace("."," ")

# %%
tokens74=nltk.word_tokenize(text74_punkt)

# %%
# DataFrame

# %%
def tæl_score_nem (tekster):
    txt=tekster
    allestrikkeord_dictionary={"ret":"Nem", "vrang":"Nem", "retmaske":"Nem", "vrangmaske":"Nem", "retstrik":"Nem", "glatstrik":"Nem", "kantmaske":"Nem", "kantmasken":"Nem", "kantmasker":"Nem", "kantmaskerne":"Nem", "løkkeopslag":"Nem", "rundpind":"Nem", "rundpinden":"Nem", "rundpinde":"Nem", "rundpindene":"Nem", "bærestykke":"Nem", "bærestykket":"Nem", "maske":"Nem", "masken":"Nem", "masker":"Nem", "maskerne":"Nem", "ærmegab":"Nem", "ærmegabet":"Nem", "maskemarkør":"Nem", "maskemarkøren":"Nem", "maskemarkører":"Nem", "maskemarkørerne":"Nem", "markør":"Nem", "markøren":"Nem", "markører":"Nem", "markørerne":"Nem", "aflukning":"Nem", "aflukningen":"Nem", "aflukninger":"Nem", "aflukningerne":"Nem",  "opslagskant":"Nem", "opslagskanten":"Nem", "opslagskanter":"Nem", "opslagskanterne":"Nem", "lænke":"Nem", "lænken":"Nem", "lænker":"Nem", "lænkerne":"Nem", "omgangsstart":"Nem", "forstykke":"Nem", "bagstykke":"Nem", "ryg":"Nem"} 
    score = []
    for w in txt:
        for k, v in allestrikkeord_dictionary.items():
            if w==k:
                score.append(v)
    Counter(score)
    return Counter(score)

# %%
def tæl_score_middel (tekster):
    txt=tekster
    allestrikkeord_dictionary={"knaphul":"Middel", "knaphullet":"Middel", "knaphuller":"Middel", "knaphullerne":"Middel", "drejet":"Middel", "drejet ret":"Middel", "drejet vrang":"Middel", "strømpepind":"Middel", "strømpepinden":"Middel", "strømpepinde":"Middel","strømpepindene":"Middel", "omslag":"Middel", "omslaget":"Middel", "omslagene":"Middel", "indtagning":"Middel", "indtagningen":"Middel", "indtagninger":"Middel", "indtagninggerne":"Middel", "rib":"Middel", "ribben":"Middel", "ribbort":"Middel", "ribpind":"Middel", "ribkant":"Middel", "ribkanten":"Middel", "ribkanter":"Middel", "ribkanterne":"Middel", "rillekant":"Middel", "rillekanten":"Middel", "rillekanter":"Middel", "rillekanterne":"Middel", "magic loop":"Middel", "magic loops":"Middel", "raglan":"Middel", "raglanen":"Middel", "raglansøm":"Middel", "raglansømmene":"Middel", "søm":"Middel", "sømme":"Middel", "sømmene":"Middel", "sømrum":"Middel", "mærketråd":"Middel", "mærketråden":"Middel", "mærketråde":"Middel", "mærketrådene":"Middel", "italiensk aflukning":"Middel", "italienske aflukninger":"Middel", "retsidepind":"Middel", "retsidepinden":"Middel", "retsidepindene":"Middel", "retsidepindene":"Middel", "maskeholder":"Middel", "maskeholderen":"Middel", "maskeholder":"Middel", "maskeholderne":"Middel", "løkkeopslag":"Middel", "løkkeopslaget":"Middel", "løkkeopslagene":"Middel", "blok":"Middel", "blokken":"Middel", "blokke":"Middel", "blokkene":"Middel"} 
    score = []
    for w in txt:
        for k, v in allestrikkeord_dictionary.items():
            if w==k:
                score.append(v)
    Counter(score)
    return Counter(score)

# %%
def tæl_score_svær (tekster):
    txt=tekster
    allestrikkeord_dictionary={"mønster":"Svær", "mønsteret":"Svær", "mønstre":"Svær", "mønstrene":"Svær", "ærmekuppel":"Svær", "ærmekuppelen":"Svær", "ærmekupler":"Svær", "ærmekuplerne":"Svær", "vendepind":"Svær", "vendepinden":"Svær", "vendepinde":"Svær", "vendepindene":"Svær", "diagram":"Svær", "boble":"Svær", "boblen":"Svær", "bobler":"Svær", "boblerne":"Svær", "dobbelt omslag":"Svær", "hulmønster":"Svær", "hulmønstre":"Svær", "montering":"Svær", "skulderaflukning":"Svær", "skulderaflukningen":"Svær", "skulderaflukninger":"Svær", "skuldersøm":"Svær", "skuldersømmen":"Svær", "skuldersømmene":"Svær", "retsidepind":"Svær", "retsidepinden":"Svær", "retsidepinde":"Svær", "retsidepindene":"Svær", "elastik":"Svær", "elastikken":"Svær", "elastikker":"Svær", "elastikkerne":"Svær", "elastiksnor":"Svær", "elastiksnoren":"Svær", "elastiksnorer":"Svær", "elastiksnorene":"Svær", "german short row":"Svær", "german short rows":"Svær", "sildebensmønster":"Svær", "sildebensmønsteret":"Svær", "overtræksindtagning":"Svær", "overtræksindtagningen":"Svær", "mønsterbort":"Svær", "sidesømsmarkør":"Svær", "sidesømsmarkøren":"Svær", "sidesømsmarkører":"Svær", "sidesømsmarkørene":"Svær", "ærmesøm":"Svær", "ærmesømmen":"Svær", "ærmesømme":"Svær", "ærmesømmene":"Svær", "raglanindtagning":"Svær", "raglanindtagningen":"Svær", "raglanindtagninger":"Svær", "raglanindtagningerne":"Svær"}
    score = []
    for w in txt:
        for k, v in allestrikkeord_dictionary.items():
            if w==k:
                score.append(v)
    Counter(score)
    return Counter(score)

# %%
def tæl_score_forkortelser (tekster):
    txt=tekster
    allestrikkeord_dictionary={ "r":"Forkortelser", "vr":"Forkortelser", "omg":"Forkortelser", "indt":"Forkortelser", "udt":"Forkortelser", "m":"Forkortelser", "p":"Forkortelser", "gent":"Forkortelser", "sm":"Forkortelser", "mm":"Forkortelser", "arb":"Forkortelser", "km":"Forkortelser", "vrs":"Forkortelser", "vrangs":"Forkortelser", "rts":"Forkortelser", "rundp":"Forkortelser", "fv":"Forkortelser", "kantm":"Forkortelser", "enkeltindt":"Forkortelser", "raglanindt":"Forkortelser", "glatst":"Forkortelser"} 
    score = []
    for w in txt:
        for k, v in allestrikkeord_dictionary.items():
            if w==k:
                score.append(v)
    Counter(score)
    return Counter(score)

# %%
def antal_tegn (tekst):
    return (len(tekst))

# %%
def tæl_score (tekster):
    txt=tekster
    allestrikkeord_dictionary={"ret":"Nem", "vrang":"Nem", "retmaske":"Nem", "vrangmaske":"Nem", "retstrik":"Nem", "glatstrik":"Nem", "kantmaske":"Nem", "kantmasken":"Nem", "kantmasker":"Nem", "kantmaskerne":"Nem", "løkkeopslag":"Nem", "rundpind":"Nem", "rundpinden":"Nem", "rundpinde":"Nem", "rundpindene":"Nem", "bærestykke":"Nem", "bærestykket":"Nem", "maske":"Nem", "masken":"Nem", "masker":"Nem", "maskerne":"Nem", "ærmegab":"Nem", "ærmegabet":"Nem", "maskemarkør":"Nem", "maskemarkøren":"Nem", "maskemarkører":"Nem", "maskemarkørerne":"Nem", "markør":"Nem", "markøren":"Nem", "markører":"Nem", "markørerne":"Nem", "aflukning":"Nem", "aflukningen":"Nem", "aflukninger":"Nem", "aflukningerne":"Nem",  "opslagskant":"Nem", "opslagskanten":"Nem", "opslagskanter":"Nem", "opslagskanterne":"Nem", "lænke":"Nem", "lænken":"Nem", "lænker":"Nem", "lænkerne":"Nem", "omgangsstart":"Nem", "forstykke":"Nem", "bagstykke":"Nem", "ryg":"Nem", "r":"Forkortelser", "vr":"Forkortelser", "omg":"Forkortelser", "indt":"Forkortelser", "udt":"Forkortelser", "m":"Forkortelser", "p":"Forkortelser", "gent":"Forkortelser", "sm":"Forkortelser", "mm":"Forkortelser", "arb":"Forkortelser", "km":"Forkortelser", "vrs":"Forkortelser", "vrangs":"Forkortelser", "rts":"Forkortelser", "rundp":"Forkortelser", "fv":"Forkortelser", "kantm":"Forkortelser", "enkeltindt":"Forkortelser", "raglanindt":"Forkortelser", "glatst":"Forkortelser", "knaphul":"Middel", "knaphullet":"Middel", "knaphuller":"Middel", "knaphullerne":"Middel", "drejet":"Middel", "drejet ret":"Middel", "drejet vrang":"Middel", "strømpepind":"Middel", "strømpepinden":"Middel", "strømpepinde":"Middel","strømpepindene":"Middel", "omslag":"Middel", "omslaget":"Middel", "omslagene":"Middel", "indtagning":"Middel", "indtagningen":"Middel", "indtagninger":"Middel", "indtagninggerne":"Middel", "rib":"Middel", "ribben":"Middel", "ribbort":"Middel", "ribpind":"Middel", "ribkant":"Middel", "ribkanten":"Middel", "ribkanter":"Middel", "ribkanterne":"Middel", "rillekant":"Middel", "rillekanten":"Middel", "rillekanter":"Middel", "rillekanterne":"Middel", "magic loop":"Middel", "magic loops":"Middel", "raglan":"Middel", "raglanen":"Middel", "raglansøm":"Middel", "raglansømmene":"Middel", "søm":"Middel", "sømme":"Middel", "sømmene":"Middel", "sømrum":"Middel", "mærketråd":"Middel", "mærketråden":"Middel", "mærketråde":"Middel", "mærketrådene":"Middel", "italiensk aflukning":"Middel", "italienske aflukninger":"Middel", "retsidepind":"Middel", "retsidepinden":"Middel", "retsidepindene":"Middel", "retsidepindene":"Middel", "maskeholder":"Middel", "maskeholderen":"Middel", "maskeholder":"Middel", "maskeholderne":"Middel", "løkkeopslag":"Middel", "løkkeopslaget":"Middel", "løkkeopslagene":"Middel", "blok":"Middel", "blokken":"Middel", "blokke":"Middel", "blokkene":"Middel", "mønster":"Svær", "mønsteret":"Svær", "mønstre":"Svær", "mønstrene":"Svær", "ærmekuppel":"Svær", "ærmekuppelen":"Svær", "ærmekupler":"Svær", "ærmekuplerne":"Svær", "vendepind":"Svær", "vendepinden":"Svær", "vendepinde":"Svær", "vendepindene":"Svær", "diagram":"Svær", "boble":"Svær", "boblen":"Svær", "bobler":"Svær", "boblerne":"Svær", "dobbelt omslag":"Svær", "hulmønster":"Svær", "hulmønstre":"Svær", "montering":"Svær", "skulderaflukning":"Svær", "skulderaflukningen":"Svær", "skulderaflukninger":"Svær", "skuldersøm":"Svær", "skuldersømmen":"Svær", "skuldersømmene":"Svær", "retsidepind":"Svær", "retsidepinden":"Svær", "retsidepinde":"Svær", "retsidepindene":"Svær", "elastik":"Svær", "elastikken":"Svær", "elastikker":"Svær", "elastikkerne":"Svær", "elastiksnor":"Svær", "elastiksnoren":"Svær", "elastiksnorer":"Svær", "elastiksnorene":"Svær", "german short row":"Svær", "german short rows":"Svær", "sildebensmønster":"Svær", "sildebensmønsteret":"Svær", "overtræksindtagning":"Svær", "overtræksindtagningen":"Svær", "mønsterbort":"Svær", "sidesømsmarkør":"Svær", "sidesømsmarkøren":"Svær", "sidesømsmarkører":"Svær", "sidesømsmarkørene":"Svær", "ærmesøm":"Svær", "ærmesømmen":"Svær", "ærmesømme":"Svær", "ærmesømmene":"Svær", "raglanindtagning":"Svær", "raglanindtagningen":"Svær", "raglanindtagninger":"Svær", "raglanindtagningerne":"Svær"}
    score = []
    for w in txt:
        for k, v in allestrikkeord_dictionary.items():
            if w==k:
                score.append(v)
    Counter(score)
    return Counter(score)

# %%
titler=["Aline Sweater", "Angela Bluse", "Ballet Bluse", "Blueberry Cream Sweater", "Bluse med kontraskanter", "Bluse med lange masker", "Cassi Cardigan", "Cherished Moments", "Colette Kort Bluse", "Dusky Rose", "Eva Sweater", "Evelyn Cardigan", "Full Moon Romance", "Good old Raglan", "Herresweater", "June Sweater", "Melody Bluse", "Newbie Sweater", "Nina Sweater", "Pepita Cardigan", "Rythmic Rain", "Serene Forest", "Sweater No.9", "Thea Top", "Violet Meadow", "Basket Weave", "Blue Shore", "Drops 226", "Drops 227", "Freya Sweater", "Gul Damebluse", "Gunhild Cardigan", "Helgi Sweater", "Herresweater med snoninger", "Lina Sweater", "Lola Sweater", "Lykkejumper", "Lærke Sweater", "Mayan Sun", "Mette Sweater", "Pepposhirt", "Prairie Rose Sweater", "Pritchard", "Sheepy Sweater", "Sophia Sweater", "Sophia Sweater Chunky", "Sweater No. 8", "Trescao Jumper", "Uda Sweater", "Vigga Sweater", "Alvi Sweater", "Anne-Cathrine Trøje", "Astridtrøje", "Athena Sweater", "Big Sur Cardigan", "Cardigan med hulmønster", "Chill Chaser", "Cloud Catcher", "Colorful Walk", "Damesweater med hulmønster", "Damesweater med striber og hulmønster", "Leaf Ring Cardigan", "Lucky Charm Sweater", "Miss Moss Sweater", "Mønstret Sweater", "Pandora Sweater", "Pearlescent Top", "Provence Dream", "Rebild Cardigan", "Smuk Snoningsweater", "Soft Journey Sweater", "Spring Parade Sweater", "Sweater med spidser og striber", "Sweet As Candy Sweater", "Tree of Life Sweater"]

# %%
tekster=[tokens0, tokens1, tokens2, tokens3, tokens4, tokens5, tokens6, tokens7, tokens8, tokens9, tokens10, tokens11, tokens12, tokens13, tokens14, tokens15, tokens16, tokens17, tokens18, tokens19, tokens20, tokens21, tokens22, tokens23, tokens24, tokens25, tokens26, tokens27, tokens28, tokens29, tokens30, tokens31, tokens32, tokens33, tokens34, tokens35, tokens36, tokens37, tokens38, tokens39, tokens40, tokens41, tokens42, tokens43, tokens44,tokens45, tokens46, tokens47, tokens48, tokens49, tokens50, tokens51, tokens52, tokens53, tokens54, tokens55,tokens56, tokens57, tokens58, tokens59, tokens60, tokens61, tokens62, tokens63, tokens64, tokens65, tokens66, tokens67, tokens68, tokens69, tokens70, tokens71, tokens72, tokens73, tokens74]

# %%
heletekster=[textpunkt0, textpunkt1, textpunkt2, textpunkt3, textpunkt4, textpunkt5, textpunkt6, textpunkt7, textpunkt8, textpunkt9, textpunkt10, textpunkt11, textpunkt12, textpunkt13, textpunkt14, textpunkt15, textpunkt16, textpunkt17, textpunkt18, textpunkt19, textpunkt20, textpunkt21, textpunkt22, textpunkt23, textpunkt24, text25_punkt, text26_punkt, text27_punkt, text28_punkt, text29_punkt, text30_punkt, text31_punkt, text32_punkt, text33_punkt, text34_punkt, text35_punkt, text36_punkt, text37_punkt, text38_punkt, text39_punkt, text40_punkt, text41_punkt, text42_punkt, text43_punkt, text44_punkt, text45_punkt, text46_punkt, text47_punkt, text48_punkt, text49_punkt, text50_punkt, text51_punkt, text52_punkt, text53_punkt, text54_punkt, text55_punkt, text56_punkt, text57_punkt, text58_punkt, text59_punkt, text60_punkt, text61_punkt, text62_punkt, text63_punkt, text64_punkt, text65_punkt, text66_punkt, text67_punkt, text68_punkt, text69_punkt, text70_punkt, text71_punkt, text72_punkt, text73_punkt, text74_punkt]

# %%
df_strik=DataFrame({"Titel":titler, "Tekst":tekster, "Hele_teksten": heletekster})

# %%
df_strik ['Score'] = df_strik.Tekst.apply(tæl_score)

# %%
df_strik ['Nem_score'] = df_strik.Tekst.apply(tæl_score_nem)

# %%
df_strik ['Middel_score'] = df_strik.Tekst.apply(tæl_score_middel)

# %%
df_strik ['Svær_score'] = df_strik.Tekst.apply(tæl_score_svær)

# %%
df_strik ['Forkortelser_score'] = df_strik.Tekst.apply(tæl_score_forkortelser)

# %%
df_strik ['Antal tegn'] = df_strik.Hele_teksten.apply(antal_tegn)

# %%
df_strik
# Out:
#                              Titel  \
# 0                    Aline Sweater
# 1                     Angela Bluse
# 2                     Ballet Bluse
# 3          Blueberry Cream Sweater
# 4          Bluse med kontraskanter
# ..                             ...
# 70            Soft Journey Sweater
# 71           Spring Parade Sweater
# 72  Sweater med spidser og striber
# 73          Sweet As Candy Sweater
# 74            Tree of Life Sweater
#
#                                                 Tekst  \
# 0   [aline, sweater, opskriftsinformation, der, st...
# 1   [angela, bluse, opskrift, information, blusen,...
# 2   [ballet, blusen, trøjen, strikkes, i, ét, styk...
# 3   [blueberry, cream, sweater, magic, loop, –, se...
# 4   [bluse, med, kontrastkanter, slå, 96, m, op, p...
# ..                                                ...
# 70  [soft, journey, sweater, forklaring, til, opsk...
# 71  [spring, parade, sweater, forklaring, til, ops...
# ...

# %%
df_strik[["Titel", "Tekst", "Score", "Nem_score", "Middel_score", "Svær_score", "Forkortelser_score", "Antal tegn"]].to_excel("AntalNemmeMiddelSværeFork.xlsx")

# %%
def antal_Tegn(tekst):
    return(len(tekst))

# %%
df_strik["antal tegn"]= df_strik.Tekst.apply(antal_Tegn)

# %%
df_strik[["Titel", "Tekst", "Score"]].to_excel("strik2.xlsx")

# %%
df_strik

# %%
def find_ord(txt, navn):
    antal=txt.count(navn)
    return antal

# %%
df_strik["antalDu"]=df_strik.Tekst.apply(find_ord, args=('du',))

# %%
df_strik["antalDig"]=df_strik.Tekst.apply(find_ord, args=('dig',))

# %%
df_strik["antalDin"]=df_strik.Tekst.apply(find_ord, args=('din',))

# %%
df_strik["antalJeg"]=df_strik.Tekst.apply(find_ord, args=('jeg',))

# %%
df_strik["antalMig"]=df_strik.Tekst.apply(find_ord, args=('mig',))

# %%
df_strik["antalMin"]=df_strik.Tekst.apply(find_ord, args=('min',))

# %%
df_strik

# %%
df_strik[["Titel", "Tekst", "Score", "antalDu", "antalDig", "antalDin", "antalJeg", "antalMig", "antalMin"]].to_excel("pron.xlsx")

# %%
# PETITE KNIT #

# %%
# Kontrastsweater

# %%
text_Kontrastsweater= 'Petiteknit/Kontrastsweater.txt'

with open(text_Kontrastsweater, encoding="utf8") as f:
    Kontrastsweater_str = f.read()

f.close()

# %%
text_lower = Kontrastsweater_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn75 = len(textpunkt)

# %%
AntalTegn75
# Out:
# 8643

# %%
textpunkt
# Out:
# '\ufeffkontrastsweater\n\nopskrift \nkontrastsweateren strikkes oppefra og ned i ét stykke  ribkanten i halsen ombukkes og sys fast på bagsiden til sidst – dette er den eneste montering, sweateren kræver, foruden enderne, der skal hæftes  der strikkes vendepinde for at danne halsudskæring  bærestykket strikkes i tre trin med tre forskellige udtagningsteknikker  ærmerne strikkes rundt på strømpepinde eller med magic loop teknik  \nkontrastsweateren har et farveskift 2/3 nede på sweateren   \n\n \nom udtagninger \nudtagninger strikkes således, at de enten hælder mod højre (udt-h) eller mod venstre (udtv)  de strikkes således: \nudt-h:  \npå retsiden: stik venstre p ind under lænken mellem to m bagfra og strik lænken r  \npå vrangsiden: stik venstre p ind under lænken forfra og strik lænken dr vr  \nudt-v:  \npå retsiden: stik venstre p ind under lænken mellem to m forfra og strik lænken dr r  \npå vrangsiden: stik venstre p ind under lænken bagfra og strik lænken vr  \n \nbærestykke \n
# ...

# %%
tokens75=nltk.word_tokenize(textpunkt)

# %%
txt=tokens75
allestrikkeord_dictionary={"ret":"Nem", "vrang":"Nem", "retmaske":"Nem", "vrangmaske":"Nem", "retstrik":"Nem", "glatstrik":"Nem", "kantmaske":"Nem", "kantmasken":"Nem", "kantmasker":"Nem", "kantmaskerne":"Nem", "løkkeopslag":"Nem", "rundpind":"Nem", "rundpinden":"Nem", "rundpinde":"Nem", "rundpindene":"Nem", "bærestykke":"Nem", "bærestykket":"Nem", "maske":"Nem", "masken":"Nem", "masker":"Nem", "maskerne":"Nem", "ærmegab":"Nem", "ærmegabet":"Nem", "maskemarkør":"Nem", "maskemarkøren":"Nem", "maskemarkører":"Nem", "maskemarkørerne":"Nem", "markør":"Nem", "markøren":"Nem", "markører":"Nem", "markørerne":"Nem", "aflukning":"Nem", "aflukningen":"Nem", "aflukninger":"Nem", "aflukningerne":"Nem",  "opslagskant":"Nem", "opslagskanten":"Nem", "opslagskanter":"Nem", "opslagskanterne":"Nem", "lænke":"Nem", "lænken":"Nem", "lænker":"Nem", "lænkerne":"Nem", "omgangsstart":"Nem", "forstykke":"Nem", "bagstykke":"Nem", "ryg":"Nem", "r":"Forkortelser", "vr":"Forkortelser", "omg":"Forkortelser", "indt":"Forkortelser", "udt":"Forkortelser", "m":"Forkortelser", "p":"Forkortelser", "gent":"Forkortelser", "sm":"Forkortelser", "mm":"Forkortelser", "arb":"Forkortelser", "km":"Forkortelser", "vrs":"Forkortelser", "vrangs":"Forkortelser", "rts":"Forkortelser", "rundp":"Forkortelser", "fv":"Forkortelser", "kantm":"Forkortelser", "enkeltindt":"Forkortelser", "raglanindt":"Forkortelser", "glatst":"Forkortelser", "knaphul":"Middel", "knaphullet":"Middel", "knaphuller":"Middel", "knaphullerne":"Middel", "drejet":"Middel", "drejet ret":"Middel", "drejet vrang":"Middel", "strømpepind":"Middel", "strømpepinden":"Middel", "strømpepinde":"Middel","strømpepindene":"Middel", "omslag":"Middel", "omslaget":"Middel", "omslagene":"Middel", "indtagning":"Middel", "indtagningen":"Middel", "indtagninger":"Middel", "indtagninggerne":"Middel", "rib":"Middel", "ribben":"Middel", "ribbort":"Middel", "ribpind":"Middel", "ribkant":"Middel", "ribkanten":"Middel", "ribkanter":"Middel", "ribkanterne":"Middel", "rillekant":"Middel", "rillekanten":"Middel", "rillekanter":"Middel", "rillekanterne":"Middel", "magic loop":"Middel", "magic loops":"Middel", "raglan":"Middel", "raglanen":"Middel", "raglansøm":"Middel", "raglansømmene":"Middel", "søm":"Middel", "sømme":"Middel", "sømmene":"Middel", "sømrum":"Middel", "mærketråd":"Middel", "mærketråden":"Middel", "mærketråde":"Middel", "mærketrådene":"Middel", "italiensk aflukning":"Middel", "italienske aflukninger":"Middel", "retsidepind":"Middel", "retsidepinden":"Middel", "retsidepindene":"Middel", "retsidepindene":"Middel", "maskeholder":"Middel", "maskeholderen":"Middel", "maskeholder":"Middel", "maskeholderne":"Middel", "løkkeopslag":"Middel", "løkkeopslaget":"Middel", "løkkeopslagene":"Middel", "blok":"Middel", "blokken":"Middel", "blokke":"Middel", "blokkene":"Middel", "mønster":"Svær", "mønsteret":"Svær", "mønstre":"Svær", "mønstrene":"Svær", "ærmekuppel":"Svær", "ærmekuppelen":"Svær", "ærmekupler":"Svær", "ærmekuplerne":"Svær", "vendepind":"Svær", "vendepinden":"Svær", "vendepinde":"Svær", "vendepindene":"Svær", "diagram":"Svær", "boble":"Svær", "boblen":"Svær", "bobler":"Svær", "boblerne":"Svær", "dobbelt omslag":"Svær", "hulmønster":"Svær", "hulmønstre":"Svær", "montering":"Svær", "skulderaflukning":"Svær", "skulderaflukningen":"Svær", "skulderaflukninger":"Svær", "skuldersøm":"Svær", "skuldersømmen":"Svær", "skuldersømmene":"Svær", "retsidepind":"Svær", "retsidepinden":"Svær", "retsidepinde":"Svær", "retsidepindene":"Svær", "elastik":"Svær", "elastikken":"Svær", "elastikker":"Svær", "elastikkerne":"Svær", "elastiksnor":"Svær", "elastiksnoren":"Svær", "elastiksnorer":"Svær", "elastiksnorene":"Svær", "german short row":"Svær", "german short rows":"Svær", "sildebensmønster":"Svær", "sildebensmønsteret":"Svær", "overtræksindtagning":"Svær", "overtræksindtagningen":"Svær", "mønsterbort":"Svær", "sidesømsmarkør":"Svær", "sidesømsmarkøren":"Svær", "sidesømsmarkører":"Svær", "sidesømsmarkørene":"Svær", "ærmesøm":"Svær", "ærmesømmen":"Svær", "ærmesømme":"Svær", "ærmesømmene":"Svær", "raglanindtagning":"Svær", "raglanindtagningen":"Svær", "raglanindtagninger":"Svær", "raglanindtagningerne":"Svær"}
score = []
for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w==k:
            score.append(v)
            
Counter(score)
# Out:
# Counter({'Nem': 1922, 'Middel': 333, 'Forkortelser': 747, 'Svær': 72})

# %%
txt = tokens75

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score75 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score75 = score75 + v
            print("Item score:", k, v)

print("Samlet score: ", score75)

# %%
RettetScore75=score75/AntalTegn75*100

# %%
RettetScore75

# %%
# Louisianasweater

# %%
text_Louisianasweater= 'Petiteknit/Louisianasweater.txt'

with open(text_Louisianasweater, encoding="utf8") as f:
    Louisianasweater_str = f.read()

f.close()

# %%
text_lower = Louisianasweater_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn76 = len(textpunkt)

# %%
AntalTegn76

# %%
textpunkt

# %%
tokens76=nltk.word_tokenize(textpunkt)

# %%
txt = tokens76

score76 = 0

for w in txt:

    for k, v in allestrikkeord_dictionary.items():

        if w == k:

            score76 = score76 + v

            print("Item score:", k, v)   

print("Samlet score: ", score76)

# %%
RettetScore76=score76/AntalTegn76*100

# %%
RettetScore76

# %%
# Marblesweater

# %%
text_Marblesweater= 'Petiteknit/Marblesweater.txt'

with open(text_Marblesweater, encoding="utf8") as f:
    Marblesweater_str = f.read()

f.close()

# %%
text_lower = Marblesweater_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn77 = len(textpunkt)

# %%
AntalTegn77

# %%
textpunkt

# %%
tokens77=nltk.word_tokenize(textpunkt)

# %%
txt = tokens77

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score77 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score77 = score77 + v

            print("Item score:", k, v)    

print("Samlet score: ", score77)

# %%
RettetScore77=score77/AntalTegn77*100

# %%
RettetScore77

# %%
# Novicesweater

# %%
text_Novicesweater= 'Petiteknit/Novicesweater.txt'

with open(text_Novicesweater, encoding="utf8") as f:
    Novicesweater_str = f.read()

f.close()

# %%
text_lower = Novicesweater_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn78 = len(textpunkt)

# %%
AntalTegn78

# %%
textpunkt

# %%
tokens78=nltk.word_tokenize(textpunkt)

# %%
txt = tokens78

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score78 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score78 = score78 + v
            print("Item score:", k, v) 

print("Samlet score: ", score78)

# %%
RettetScore78=score78/AntalTegn78*100

# %%
RettetScore78

# %%
# Septembersweater

# %%
text_Septembersweater= 'Petiteknit/Septembersweater.txt'

with open(text_Septembersweater, encoding="utf8") as f:
    Septembersweater_str = f.read()

f.close()

# %%
text_lower = Septembersweater_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn79 = len(textpunkt)

# %%
AntalTegn79

# %%
textpunkt

# %%
tokens79=nltk.word_tokenize(textpunkt)

# %%
txt = tokens79

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "ma
print("Samlet score: ", score79)

# %%
# Stockholmsweater

# %%
text_Stockholmsweater= 'Petiteknit/Stockholmsweater.txt'

with open(text_Stockholmsweater, encoding="utf8") as f:
    Stockholmsweater_str = f.read()

f.close()

# %%
text_lower = Stockholmsweater_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn80 = len(textpunkt)

# %%
AntalTegn80

# %%
textpunkt

# %%
tokens80=nltk.word_tokenize(textpunkt)

# %%
txt = tokens80

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score80 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score80 = score80 + v

            print("Item score:", k, v)

print("Samlet score: ", score80)

# %%
RettetScore80=score80/AntalTegn80*100

# %%
RettetScore80

# %%
# Striber_på_langs_sweater

# %%
text_Striber_på_langs_sweater= 'Petiteknit/Striber_på_langs_sweater.txt'

with open(text_Striber_på_langs_sweater, encoding="utf8") as f:
    Striber_på_langs_sweater_str = f.read()
    
f.close()

# %%
text_lower = Striber_på_langs_sweater_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn81 = len(textpunkt)

# %%
AntalTegn81

# %%
textpunkt

# %%
tokens81=nltk.word_tokenize(textpunkt)

# %%
txt = tokens81

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "aflukninger":1, "aflukningerne":1,  "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "ribbort":2, "ribpind":2, "ribkant":2, "ribkanten":2, "ribkanter":2, "ribkanterne":2, "rillekant":2, "rillekanten":2, "rillekanter":2, "rillekanterne":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "raglansøm":2, "raglansømmene":2, "søm":2, "sømme":2, "sømmene":2, "sømrum":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score81 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score81 = score81 + v

            print("Item score:", k, v)          

print("Samlet score: ", score81)

# %%
RettetScore81=score81/AntalTegn81*100

# %%
RettetScore81

# %%
# Sundaysweater

# %%
text_Sundaysweater= 'Petiteknit/Sundaysweater.txt'

with open(text_Sundaysweater, encoding="utf8") as f:
    Sundaysweater_str = f.read()

f.close()

# %%
text_lower = Sundaysweater_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn82 = len(textpunkt)

# %%
AntalTegn82

# %%
textpunkt

# %%
tokens82=nltk.word_tokenize(textpunkt)

# %%
txt = tokens82

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "bærestykke":1, "bærestykket":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1
score83 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score83 = score83 + v
            print("Item score:", k, v)

print("Samlet score: ", score83)

# %%
RettetScore83=score83/AntalTegn83*100

# %%
RettetScore83

# %%
# Festival_kjole

# %%
text_Festival_kjole= 'Petiteknit/Festival_kjole.txt'

with open(text_Festival_kjole, encoding="utf8") as f:
    Festival_kjole_str = f.read()

f.close()

# %%
text_lower = Festival_kjole_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn84 = len(textpunkt)

# %%
AntalTegn84

# %%
textpunkt

# %%
tokens84=nltk.word_tokenize(textpunkt)

# %%
txt = tokens84

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score84 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score84 = score84 + v

            print("Item score:", k, v)

print("Samlet score: ", score84)

# %%
RettetScore84=score84/AntalTegn84*100

# %%
RettetScore84

# %%
# Sunday_Tee

# %%
text_Sunday_Tee= 'Petiteknit/Sunday_Tee.txt'

with open(text_Sunday_Tee, encoding="utf8") as f:
    Sunday_Tee_str = f.read()
    
f.close()

# %%
text_lower = Sunday_Tee_str.lower()

# %%
textpunkt = text_lower.replace("."," ")

# %%
AntalTegn85 = len(textpunkt)

# %%
AntalTegn85

# %%
textpunkt

# %%
tokens85=nltk.word_tokenize(textpunkt)

# %%
txt = tokens85

allestrikkeord_dictionary={"ret":1, "vrang":1, "retmaske":1, "vrangmaske":1, "retstrik":1, "glatstrik":1, "kantmaske":1, "kantmasken":1, "kantmasker":1, "kantmaskerne":1, "løkkeopslag":1, "rundpind":1, "rundpinden":1, "rundpinde":1, "rundpindene":1, "maske":1, "masken":1, "masker":1, "maskerne":1, "ærmegab":1, "ærmegabet":1, "maskemarkør":1, "maskemarkøren":1, "maskemarkører":1, "maskemarkørerne":1, "markør":1, "markøren":1, "markører":1, "markørerne":1, "aflukning":1, "aflukningen":1, "opslagskant":1, "opslagskanten":1, "opslagskanter":1, "opslagskanterne":1, "lænke":1, "lænken":1, "lænker":1, "lænkerne":1, "omgangsstart":1, "forstykke":1, "bagstykke":1, "ryg":1, "r":1, "vr":1, "omg":1, "indt":1, "udt":1, "m":1, "p":1, "gent":1, "sm":1, "mm":1, "arb":1, "km":1, "vrs”:1, “vrangs":1, "rts":1, "rundp":1, "fv":1, "kantm":1, "enkeltindt":1, "raglanindt":1, "glatst":1, "knaphul":2, "knaphullet":2, "knaphuller":2, "knaphullerne":2, "drejet":2, "drejet ret":2, "drejet vrang":2, "strømpepind":2, "strømpepinden":2, "strømpepinde":2,"strømpepindene":2, "omslag":2, "omslaget":2, "omslagene":2, "indtagning":2, "indtagningen":2, "indtagninger":2, "indtagninggerne":2, "rib":2, "ribben":2, "magic loop":2, "magic loops":2, "raglan":2, "raglanen":2, "mærketråd":2, "mærketråden”:2, “mærketråde":2, "mærketrådene":2, "italiensk aflukning":2, "italienske aflukninger":2, "retsidepind":2, "retsidepinden":2, "retsidepindene":2, "retsidepindene":2, "maskeholder":2, "maskeholderen":2, "maskeholder":2, "maskeholderne":2, "løkkeopslag":2, "løkkeopslaget":2, "løkkeopslagene":2, "blok":2, "blokken":2, "blokke":2, "blokkene":2, "mønster":3, "mønsteret":3, "mønstre":3, "mønstrene":3, "ærmekuppel":3, "ærmekuppelen":3, "ærmekupler":3, "ærmekuplerne":3, "vendepind":3, "vendepinden":3, "vendepinde":3, "vendepindene":3, "diagram":3, "boble":3, "boblen":3, "bobler":3, "boblerne":3, "dobbelt omslag":3, "hulmønster":3, "hulmønstre":3, "montering":3, "skulderaflukning":3, "skulderaflukningen":3, "skulderaflukninger":3, "skuldersøm":3, "skuldersømmen":3, "skuldersømmene":3, "retsidepind":3, "retsidepinden":3, "retsidepinde":3, "retsidepindene":3, "elastik":3, "elastikken":3, "elastikker":3, "elastikkerne":3, "elastiksnor":3, "elastiksnoren":3, "elastiksnorer":3, "elastiksnorene":3, "german short row":3, "german short rows":3, "sildebensmønster":3, "sildebensmønsteret":3, "overtræksindtagning":3, "overtræksindtagningen":3, "mønsterbort":3, "sidesømsmarkør":3, "sidesømsmarkøren":3, "sidesømsmarkører":3, "sidesømsmarkørene":3, "ærmesøm":3, "ærmesømmen":3, "ærmesømme":3, "ærmesømmene":3, "raglanindtagning":3, "raglanindtagningen":3, "raglanindtagninger":3, "raglanindtagningerne":3}
score85 = 0

for w in txt:
    for k, v in allestrikkeord_dictionary.items():
        if w == k:
            score85 = score85 + v

            print("Item score:", k, v)

print("Samlet score: ", score85)

# %%
RettetScore85=score85/AntalTegn85*100

# %%
RettetScore85

# %%
titler_PK=["Kontrastsweater", "Louisianasweater", "Marblesweater", "Novicesweater", "Septembersweater", "Stockholmsweater", "Striber på langs sweater", "Sundaysweater", "Zippersweater", "Festivalkjole", "Sunday Tee"]

# %%
tekster_PK=[tokens75, tokens76, tokens77, tokens78, tokens79, tokens80, tokens81, tokens82, tokens83, tokens84, tokens85]

# %%
df_petiteknit=DataFrame({"Titel":titler_PK, "Tekst":tekster_PK})

# %%
df_petiteknit

# %%
def find_ord(txt, navn):
    antal=txt.count(navn)
    return antal

# %%
df_petiteknit["antalDu"]=df_petiteknit.Tekst.apply(find_ord, args=('du',))

# %%
df_petiteknit["antalDig"]=df_petiteknit.Tekst.apply(find_ord, args=('dig',))

# %%
df_petiteknit["antalDin"]=df_petiteknit.Tekst.apply(find_ord, args=('din',))

# %%
df_petiteknit["antalJeg"]=df_petiteknit.Tekst.apply(find_ord, args=('jeg',))

# %%
df_petiteknit["antalMig"]=df_petiteknit.Tekst.apply(find_ord, args=('mig',))

# %%
df_petiteknit["antalMin"]=df_petiteknit.Tekst.apply(find_ord, args=('min',))

# %%
def tæl_score_PK (tekster_PK):
    txt=tekster_PK
    allestrikkeord_dictionary={"ret":"Nem", "vrang":"Nem", "retmaske":"Nem", "vrangmaske":"Nem", "retstrik":"Nem", "glatstrik":"Nem", "kantmaske":"Nem", "kantmasken":"Nem", "kantmasker":"Nem", "kantmaskerne":"Nem", "løkkeopslag":"Nem", "rundpind":"Nem", "rundpinden":"Nem", "rundpinde":"Nem", "rundpindene":"Nem", "bærestykke":"Nem", "bærestykket":"Nem", "maske":"Nem", "masken":"Nem", "masker":"Nem", "maskerne":"Nem", "ærmegab":"Nem", "ærmegabet":"Nem", "maskemarkør":"Nem", "maskemarkøren":"Nem", "maskemarkører":"Nem", "maskemarkørerne":"Nem", "markør":"Nem", "markøren":"Nem", "markører":"Nem", "markørerne":"Nem", "aflukning":"Nem", "aflukningen":"Nem", "aflukninger":"Nem", "aflukningerne":"Nem",  "opslagskant":"Nem", "opslagskanten":"Nem", "opslagskanter":"Nem", "opslagskanterne":"Nem", "lænke":"Nem", "lænken":"Nem", "lænker":"Nem", "lænkerne":"Nem", "omgangsstart":"Nem", "forstykke":"Nem", "bagstykke":"Nem", "ryg":"Nem", "r":"Forkortelser", "vr":"Forkortelser", "omg":"Forkortelser", "indt":"Forkortelser", "udt":"Forkortelser", "m":"Forkortelser", "p":"Forkortelser", "gent":"Forkortelser", "sm":"Forkortelser", "mm":"Forkortelser", "arb":"Forkortelser", "km":"Forkortelser", "vrs":"Forkortelser", "vrangs":"Forkortelser", "rts":"Forkortelser", "rundp":"Forkortelser", "fv":"Forkortelser", "kantm":"Forkortelser", "enkeltindt":"Forkortelser", "raglanindt":"Forkortelser", "glatst":"Forkortelser", "knaphul":"Middel", "knaphullet":"Middel", "knaphuller":"Middel", "knaphullerne":"Middel", "drejet":"Middel", "drejet ret":"Middel", "drejet vrang":"Middel", "strømpepind":"Middel", "strømpepinden":"Middel", "strømpepinde":"Middel","strømpepindene":"Middel", "omslag":"Middel", "omslaget":"Middel", "omslagene":"Middel", "indtagning":"Middel", "indtagningen":"Middel", "indtagninger":"Middel", "indtagninggerne":"Middel", "rib":"Middel", "ribben":"Middel", "ribbort":"Middel", "ribpind":"Middel", "ribkant":"Middel", "ribkanten":"Middel", "ribkanter":"Middel", "ribkanterne":"Middel", "rillekant":"Middel", "rillekanten":"Middel", "rillekanter":"Middel", "rillekanterne":"Middel", "magic loop":"Middel", "magic loops":"Middel", "raglan":"Middel", "raglanen":"Middel", "raglansøm":"Middel", "raglansømmene":"Middel", "søm":"Middel", "sømme":"Middel", "sømmene":"Middel", "sømrum":"Middel", "mærketråd":"Middel", "mærketråden":"Middel", "mærketråde":"Middel", "mærketrådene":"Middel", "italiensk aflukning":"Middel", "italienske aflukninger":"Middel", "retsidepind":"Middel", "retsidepinden":"Middel", "retsidepindene":"Middel", "retsidepindene":"Middel", "maskeholder":"Middel", "maskeholderen":"Middel", "maskeholder":"Middel", "maskeholderne":"Middel", "løkkeopslag":"Middel", "løkkeopslaget":"Middel", "løkkeopslagene":"Middel", "blok":"Middel", "blokken":"Middel", "blokke":"Middel", "blokkene":"Middel", "mønster":"Svær", "mønsteret":"Svær", "mønstre":"Svær", "mønstrene":"Svær", "ærmekuppel":"Svær", "ærmekuppelen":"Svær", "ærmekupler":"Svær", "ærmekuplerne":"Svær", "vendepind":"Svær", "vendepinden":"Svær", "vendepinde":"Svær", "vendepindene":"Svær", "diagram":"Svær", "boble":"Svær", "boblen":"Svær", "bobler":"Svær", "boblerne":"Svær", "dobbelt omslag":"Svær", "hulmønster":"Svær", "hulmønstre":"Svær", "montering":"Svær", "skulderaflukning":"Svær", "skulderaflukningen":"Svær", "skulderaflukninger":"Svær", "skuldersøm":"Svær", "skuldersømmen":"Svær", "skuldersømmene":"Svær", "retsidepind":"Svær", "retsidepinden":"Svær", "retsidepinde":"Svær", "retsidepindene":"Svær", "elastik":"Svær", "elastikken":"Svær", "elastikker":"Svær", "elastikkerne":"Svær", "elastiksnor":"Svær", "elastiksnoren":"Svær", "elastiksnorer":"Svær", "elastiksnorene":"Svær", "german short row":"Svær", "german short rows":"Svær", "sildebensmønster":"Svær", "sildebensmønsteret":"Svær", "overtræksindtagning":"Svær", "overtræksindtagningen":"Svær", "mønsterbort":"Svær", "sidesømsmarkør":"Svær", "sidesømsmarkøren":"Svær", "sidesømsmarkører":"Svær", "sidesømsmarkørene":"Svær", "ærmesøm":"Svær", "ærmesømmen":"Svær", "ærmesømme":"Svær", "ærmesømmene":"Svær", "raglanindtagning":"Svær", "raglanindtagningen":"Svær", "raglanindtagninger":"Svær", "raglanindtagningerne":"Svær"}
    score = []
    for w in txt:
        for k, v in allestrikkeord_dictionary.items():
            if w==k:
                score.append(v)
    Counter(score)
    return Counter(score)

# %%
df_petiteknit["Score"]=df_petiteknit.Tekst.apply(tæl_score_PK)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12692/2302071233.py in <module>
# ----> 1 df_petiteknit["Score"]=df_petiteknit.Tekst.apply(tæl_score_PK)
#
# NameError: name 'df_petiteknit' is not defined

# %%
df_petiteknit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12692/3406230329.py in <module>
# ----> 1 df_petiteknit
#
# NameError: name 'df_petiteknit' is not defined

# %%
df_petiteknit[["Titel", "Tekst", "Score", "antalDu", "antalDig", "antalDin", "antalJeg", "antalMig", "antalMin"]].to_excel("strik3.xlsx")

# %%
svære_df=df_strik[df_strik.Score.apply(lambda x: x['Svær']>=5)]

# %%
middel_df=df_strik[df_strik.Score.apply(lambda x: x['Middel']>=10)]

# %%
nem_df=df_strik[df_strik.Score.apply(lambda x: x['Svær']<=1)]

# %%
nem_df

# %%
df_strik[["Titel", "Tekst", "Score"]].to_excel("strik1.xlsx")

# %%
svær=[]
middel=[]
nem=[]

def resultat (i):
    resultat1= []
    
    
    for i in df_strik["Titel"]:
        if i in svære_df["Titel"].values:
            svær.append(i)
        elif i in middel_df["Titel"].values:
            middel.append(i)
        elif i in nem_df["Titel"].values:
            nem.append(i)

# %%
resultat("Tree of Life Sweater")

# %%
print(svær)

# %%
def find_niveau (i):
    
    if i in svær:
        print (i+": Dette er en svær opskrift")
    elif i in middel:
        print (i+": Dette er en middel opskrift")
    elif i in nem:
        print (i+": Dette er en nem opskrift")

# %%
find_niveau("Smuk Snoningsweater")
